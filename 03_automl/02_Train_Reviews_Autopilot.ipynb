# %% [markdown]
# # NOTE:  THIS NOTEBOOK RUNS FOR 30+ MINUTES.
#
# # PLEASE BE PATIENT

# %% [markdown]
# # Train a Model with SageMaker Autopilot
#
# We will use Autopilot to predict the star rating of customer reviews. Autopilot implements a transparent approach to AutoML.
#
# For more details on Autopilot, have a look at this [**Amazon Science Publication**](https://www.amazon.science/publications/amazon-sagemaker-autopilot-a-white-box-automl-solution-at-scale).
#
# [![](img/amazon_science.png)](https://www.amazon.science/publications/amazon-sagemaker-autopilot-a-white-box-automl-solution-at-scale)

# %% [markdown]
# <img src="img/autopilot-transparent.png" width="80%" align="left">

# %% [markdown]
# # Introduction

# %% [markdown]
# Amazon SageMaker Autopilot is a service to perform automated machine learning (AutoML) on your datasets.  Autopilot is available through the UI or AWS SDK.  In this notebook, we will use the AWS SDK to create and deploy a text processing and star rating classification machine learning pipeline.

# %% [markdown]
# # Setup
#
# Let's start by specifying:
#
# * The S3 bucket and prefix to use to train our model.  _Note:  This should be in the same region as this notebook._
# * The IAM role of this notebook needs access to your data.

# %% [markdown]
# # Notes
# * This notebook will take some time to finish.
#
# * You can start this notebook and continue to the next notebooks whenever you are waiting for the current notebook to finish.

# %% [markdown]
# # Checking Pre-Requisites From Previous Notebook

# %%
# %store -r autopilot_train_s3_uri

# %%
try:
    autopilot_train_s3_uri
    print("[OK]")
except NameError:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] PLEASE RUN THE PREVIOUS 01_PREPARE_DATASET_AUTOPILOT NOTEBOOK.")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# [OK]

# %%
print(autopilot_train_s3_uri)
# Out:
# s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv

# %%
if not autopilot_train_s3_uri:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] PLEASE RUN THE PREVIOUS 01_PREPARE_DATASET_AUTOPILOT NOTEBOOK.")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
else:
    print("[OK]")
# Out:
# [OK]

# %%
import boto3
import sagemaker
import pandas as pd
import json

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# # Training Data

# %%
print(autopilot_train_s3_uri)
# Out:
# s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv

# %%
# !aws s3 ls $autopilot_train_s3_uri
# Out:
# 2024-06-30 15:41:56   13660984 amazon_reviews_us_Digital_Software_v1_00_autopilot.csv

# %% [markdown]
# ## See our prepared training data which we use as input for Autopilot

# %%
# !aws s3 cp $autopilot_train_s3_uri ./tmp/
# Out:
# download: s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv to tmp/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv

# %%
import csv

df = pd.read_csv("./tmp/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv")
df.head()
# Out:
#    star_rating                                        review_body
# 0            4  Over all is good, responsive and quick. The in...
# 1            3  Cannot display on my larger monitor like Quick...
# 2            1  i think I will have to remove this from my com...
# 3            3  First of all the thing that I dislike is that ...
# 4            5  Doing taxes each year is not my idea of fun, b...

# %% [markdown]
# # Setup the S3 Location for the Autopilot-Generated Assets
# This include Jupyter Notebooks (Analysis), Python Scripts (Feature Engineering), and Trained Models.

# %%
prefix_model_output = "models/autopilot"

model_output_s3_uri = "s3://{}/{}".format(bucket, prefix_model_output)

print(model_output_s3_uri)
# Out:
# s3://sagemaker-us-east-1-891377026966/models/autopilot

# %%
max_candidates = 3

job_config = {
    "CompletionCriteria": {
        "MaxRuntimePerTrainingJobInSeconds": 900,
        "MaxCandidates": max_candidates,
        "MaxAutoMLJobRuntimeInSeconds": 5400,
    },
}

input_data_config = [
    {
        "DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "{}".format(autopilot_train_s3_uri)}},
        "TargetAttributeName": "star_rating",
    }
]

output_data_config = {"S3OutputPath": "{}".format(model_output_s3_uri)}

# %% [markdown]
# # Check For Existing Autopilot Jobs

# %%
existing_jobs_response = sm.list_auto_ml_jobs()

# %%
num_existing_jobs = 0
running_jobs = 0

if "AutoMLJobSummaries" in existing_jobs_response.keys():
    job_list = existing_jobs_response["AutoMLJobSummaries"]
    num_existing_jobs = len(job_list)
    # print('[INFO] You already created {} Autopilot job(s) in this account.'.format(num_existing_jobs))
    for j in job_list:
        if "AutoMLJobStatus" in j.keys():
            if j["AutoMLJobStatus"] == "InProgress":
                running_jobs = running_jobs + 1
    print("[INFO] You have {} Autopilot job(s) currently running << Should be 0 jobs.".format(running_jobs))
else:
    print("[OK] Please continue.")
# Out:
# [INFO] You have 0 Autopilot job(s) currently running << Should be 0 jobs.

# %% [markdown]
# # Launch the SageMaker Autopilot Job

# %%
from time import gmtime, strftime, sleep

# %%
# %store -r auto_ml_job_name

try:
    auto_ml_job_name
except NameError:
    timestamp_suffix = strftime("%d-%H-%M-%S", gmtime())
    auto_ml_job_name = "automl-dm-" + timestamp_suffix
    print("Created AutoMLJobName: " + auto_ml_job_name)
# Out:
# no stored variable or alias auto_ml_job_name
# Created AutoMLJobName: automl-dm-30-15-44-36

# %%
print(auto_ml_job_name)
# Out:
# automl-dm-30-15-44-36

# %%
# %store auto_ml_job_name
# Out:
# Stored 'auto_ml_job_name' (str)

# %%
max_running_jobs = 1

if running_jobs < max_running_jobs:  # Limiting to max. 1 Jobs
    try:
        sm.create_auto_ml_job(
            AutoMLJobName=auto_ml_job_name,
            InputDataConfig=input_data_config,
            OutputDataConfig=output_data_config,
            AutoMLJobConfig=job_config,
            RoleArn=role,
        )
        print("[OK] Autopilot Job {} created.".format(auto_ml_job_name))
        running_jobs = running_jobs + 1
    except:
        print(
            "[INFO] You have already launched an Autopilot job. Please continue see the output of this job.".format(
                running_jobs
            )
        )
else:
    print(
        "[INFO] You have already launched {} Autopilot job(s). Please continue see the output of the running job.".format(
            running_jobs
        )
    )
# Out:
# [OK] Autopilot Job automl-dm-30-15-44-36 created.

# %% [markdown]
# # Track the Progress of the Autopilot Job
#
# SageMaker Autopilot job consists of the following high-level steps:
# * _Data Analysis_ where the data is summarized and analyzed to determine which feature engineering techniques, hyper-parameters, and models to explore.
# * _Feature Engineering_ where the data is scrubbed, balanced, combined, and split into train and validation.
# * _Model Training and Tuning_ where the top performing features, hyper-parameters, and models are selected and trained.
#
# <img src="img/autopilot-steps.png" width="90%" align="left">

# %% [markdown]
# **Autopilot Research Paper:
# https://assets.amazon.science/e8/8b/2366b1ab407990dec96e55ee5664/amazon-sagemaker-autopilot-a-white-box-automl-solution-at-scale.pdf**

# %% [markdown]
# # Analyzing Data and Generate Notebooks

# %%
job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)

while (
    "AutoMLJobStatus" not in job_description_response.keys()
    and "AutoMLJobSecondaryStatus" not in job_description_response.keys()
):
    job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    print("[INFO] Autopilot Job has not yet started. Please wait. ")
    print(json.dumps(job_description_response, indent=4, sort_keys=True, default=str))
    print("[INFO] Waiting for Autopilot Job to start...")
    sleep(15)

print("[OK] AutoMLJob started.")
# Out:
# [OK] AutoMLJob started.

# %% [markdown]
# # Review the SageMaker `Processing Jobs`
# * First Processing Job (Data Splitter) checks the data sanity, performs stratified shuffling and splits the data into training and validation.
# * Second Processing Job (Candidate Generator) first streams through the data to compute statistics for the dataset. Then, uses these statistics to identify the problem type, and possible types of every column-predictor: numeric, categorical, natural language, etc.

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/processing-jobs/">Processing Jobs</a></b>'.format(
            region
        )
    )
)
# Out:
# /tmp/ipykernel_270/1906276573.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/processing-jobs/">Processing Jobs</a></b>

# %% [markdown]
# # The Next Cell Will Show `InProgress` For A Few Minutes.
#
# ## _Please be patient._

# %%
# %%time

job_status = job_description_response["AutoMLJobStatus"]
job_sec_status = job_description_response["AutoMLJobSecondaryStatus"]

if job_status not in ("Stopped", "Failed"):
    while job_status in ("InProgress") and job_sec_status in ("Starting", "AnalyzingData"):
        job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job_description_response["AutoMLJobStatus"]
        job_sec_status = job_description_response["AutoMLJobSecondaryStatus"]
        print(job_status, job_sec_status)
        sleep(15)
    print("[OK] Data analysis phase completed.\n")

print(json.dumps(job_description_response, indent=4, sort_keys=True, default=str))
# Out:
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress FeatureEngineering
# [OK] Data analysis phase completed.
#
# {
#     "AutoMLJobArn": "arn:aws:sagemaker:us-east-1:891377026966:automl-job/automl-dm-30-15-44-36",
#     "AutoMLJobArtifacts": {
#         "CandidateDefinitionNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb",
#         "DataExplorationNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb"
#     },
#     "AutoMLJobConfig": {
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         }
#     },
#     "AutoMLJobName": "automl-dm-30-15-44-36",
#     "AutoMLJobSecondaryStatus": "FeatureEngineering",
#     "AutoMLJobStatus": "InProgress",
#     "CreationTime": "2024-06-30 15:45:22.470000+00:00",
#     "GenerateCandidateDefinitionsOnly": false,
#     "InputDataConfig": [
#         {
#             "ChannelType": "training",
#             "ContentType": "text/csv;header=present",
#             "DataSource": {
#                 "S3DataSource": {
#                     "S3DataType": "S3Prefix",
#                     "S3Uri": "s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv"
#                 }
#             },
#             "TargetAttributeName": "star_rating"
#         }
#     ],
#     "LastModifiedTime": "2024-06-30 15:53:33.683000+00:00",
#     "OutputDataConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-891377026966/models/autopilot"
#     },
#     "ResolvedAttributes": {
#         "AutoMLJobObjective": {
#             "MetricName": "Accuracy"
#         },
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         },
#         "ProblemType": "MulticlassClassification"
#     },
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "1748",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 30 Jun 2024 15:53:38 GMT",
#             "x-amzn-requestid": "86a0132c-e4b2-46c4-9337-cdcff958302b"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "86a0132c-e4b2-46c4-9337-cdcff958302b",
#         "RetryAttempts": 0
#     },
#     "RoleArn": "arn:aws:iam::891377026966:role/service-role/AmazonSageMaker-ExecutionRole-20240628T190970"
# }
# CPU times: user 238 ms, sys: 34.6 ms, total: 273 ms
# Wall time: 3min 31s

# %% [markdown]
# # View Generated Notebook Samples
# Once data analysis is complete, SageMaker AutoPilot generates two notebooks:
# * Data Exploration
# * Candidate Definition

# %% [markdown]
# # Waiting For Generated Notebooks

# %%
job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)

while "AutoMLJobArtifacts" not in job_description_response.keys():
    job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    print("[INFO] Autopilot Job has not yet generated the artifacts. Please wait. ")
    print(json.dumps(job_description_response, indent=4, sort_keys=True, default=str))
    print("[INFO] Waiting for AutoMLJobArtifacts...")
    sleep(15)

print("[OK] AutoMLJobArtifacts generated.")
# Out:
# [OK] AutoMLJobArtifacts generated.

# %%
job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)

while "DataExplorationNotebookLocation" not in job_description_response["AutoMLJobArtifacts"].keys():
    job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    print("[INFO] Autopilot Job has not yet generated the notebooks. Please wait. ")
    print(json.dumps(job_description_response, indent=4, sort_keys=True, default=str))
    print("[INFO] Waiting for DataExplorationNotebookLocation...")
    sleep(15)

print("[OK] DataExplorationNotebookLocation found.")
# Out:
# [OK] DataExplorationNotebookLocation found.

# %%
generated_resources = job_description_response["AutoMLJobArtifacts"]["DataExplorationNotebookLocation"]
download_path = generated_resources.rsplit("/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb")[0]
job_id = download_path.rsplit("/", 1)[-1]

# %%
from IPython.core.display import display, HTML

if not job_id:
    print("No AutoMLJobArtifacts found.")
else:
    display(
        HTML(
            '<b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/{}/{}/{}/sagemaker-automl-candidates/{}/">S3 Generated Resources</a></b>'.format(
                bucket, prefix_model_output, auto_ml_job_name, job_id
            )
        )
    )
# Out:
# /tmp/ipykernel_270/1834909452.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/">S3 Generated Resources</a></b>

# %% [markdown]
# # Download Generated Notebooks & Code

# %%
print(download_path)
# Out:
# s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872

# %%
try:
    # !aws s3 cp --recursive $download_path .
except:
    print('Could not download the generated resources. Make sure the path is correct.')
# Out:
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/MANIFEST.in to generated_module/MANIFEST.in
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/candidate_data_processors/dpp0.py to generated_module/candidate_data_processors/dpp0.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/README.md to generated_module/README.md
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/candidate_data_processors/dpp1.py to generated_module/candidate_data_processors/dpp1.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/setup.py to generated_module/setup.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/__init__.py to notebooks/sagemaker_automl/__init__.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/candidate_data_processors/trainer.py to generated_module/candidate_data_processors/trainer.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/candidate_data_processors/dpp2.py to generated_module/candidate_data_processors/dpp2.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/generated_module/candidate_data_processors/sagemaker_serve.py to generated_module/candidate_data_processors/sagemaker_serve.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb to notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/config.py to notebooks/sagemaker_automl/config.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/common.py to notebooks/sagemaker_automl/common.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/interactive_runner.py to notebooks/sagemaker_automl/interactive_runner.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/README.md to notebooks/sagemaker_automl/README.md
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/steps.py to notebooks/sagemaker_automl/steps.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/sagemaker_automl/local_candidate.py to notebooks/sagemaker_automl/local_candidate.py
# download: s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb to notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# # Review The Generated Resources:

# %%
# !ls ./generated_module/candidate_data_processors
# Out:
# dpp0.py  dpp1.py  dpp2.py  sagemaker_serve.py  trainer.py

# %%
# !ls ./notebooks
# Out:
# SageMakerAutopilotCandidateDefinitionNotebook.ipynb  sagemaker_automl
# SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Watch out for SageMaker `Training Jobs` and `Batch Transform Jobs` to start.
#
# * This is the candidate exploration phase.
# * Each python script code for data-processing is executed inside a SageMaker framework container as a training job, followed by transform job.
#
# Note, that feature preprocessing part of each pipeline has all hyper parameters fixed, i.e. does not require tuning, thus feature preprocessing step can be done prior runing the hyper parameter optimization job.
#
# It outputs up to 10 variants of transformed data, therefore algorithms for each pipeline are set to use
# the respective transformed data.
#
# <img src="img/autopilot-steps.png" width="90%" align="left">

# %% [markdown]
# **Autopilot Research Paper:
# https://assets.amazon.science/e8/8b/2366b1ab407990dec96e55ee5664/amazon-sagemaker-autopilot-a-white-box-automl-solution-at-scale.pdf**

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/jobs/">Training Jobs</a></b>'.format(
            region
        )
    )
)
# Out:
# /tmp/ipykernel_270/3328794605.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs/">Training Jobs</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/transform-jobs/">Batch Transform Jobs</a></b>'.format(
            region
        )
    )
)
# Out:
# /tmp/ipykernel_270/790293257.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/transform-jobs/">Batch Transform Jobs</a></b>

# %% [markdown]
# # The Next Cell Will Show `InProgress` For A Few Minutes.
#
# ## _Please be patient._ ##

# %%
# %%time

job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_status = job_description_response["AutoMLJobStatus"]
job_sec_status = job_description_response["AutoMLJobSecondaryStatus"]
print(job_status)
print(job_sec_status)
if job_status not in ("Stopped", "Failed"):
    while job_status in ("InProgress") and job_sec_status in ("FeatureEngineering"):
        job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job_description_response["AutoMLJobStatus"]
        job_sec_status = job_description_response["AutoMLJobSecondaryStatus"]
        print(job_status, job_sec_status)
        sleep(15)
    print("[OK] Feature engineering phase completed.\n")

print(json.dumps(job_description_response, indent=4, sort_keys=True, default=str))
# Out:
# InProgress
# MergingAutoMLTaskReports
# [OK] Feature engineering phase completed.
#
# {
#     "AutoMLJobArn": "arn:aws:sagemaker:us-east-1:891377026966:automl-job/automl-dm-30-15-44-36",
#     "AutoMLJobArtifacts": {
#         "CandidateDefinitionNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb",
#         "DataExplorationNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb"
#     },
#     "AutoMLJobConfig": {
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         }
#     },
#     "AutoMLJobName": "automl-dm-30-15-44-36",
#     "AutoMLJobSecondaryStatus": "MergingAutoMLTaskReports",
#     "AutoMLJobStatus": "InProgress",
#     "BestCandidate": {
#         "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#         "CandidateProperties": {
#             "CandidateMetrics": [
#                 {
#                     "MetricName": "F1macro",
#                     "Set": "Validation",
#                     "StandardMetricName": "F1macro",
#                     "Value": 0.45320001244544983
#                 },
#                 {
#                     "MetricName": "PrecisionMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "PrecisionMacro",
#                     "Value": 0.4521999955177307
#                 },
#                 {
#                     "MetricName": "Accuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "Accuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "BalancedAccuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "BalancedAccuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "LogLoss",
#                     "Set": "Validation",
#                     "StandardMetricName": "LogLoss",
#                     "Value": 1.2926299571990967
#                 },
#                 {
#                     "MetricName": "RecallMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "RecallMacro",
#                     "Value": 0.45486000180244446
#                 }
#             ]
#         },
#         "CandidateStatus": "Completed",
#         "CandidateSteps": [
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepType": "AWS::SageMaker::TransformJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             }
#         ],
#         "CreationTime": "2024-06-30 16:03:37+00:00",
#         "EndTime": "2024-06-30 16:07:17+00:00",
#         "FinalAutoMLJobObjectiveMetric": {
#             "MetricName": "validation:accuracy",
#             "StandardMetricName": "Accuracy",
#             "Value": 0.45486000180244446
#         },
#         "InferenceContainers": [
#             {
#                 "Environment": {
#                     "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                     "AUTOML_TRANSFORM_MODE": "feature-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "MAX_CONTENT_LENGTH": "20971520",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             }
#         ],
#         "LastModifiedTime": "2024-06-30 16:15:28.633000+00:00",
#         "ObjectiveStatus": "Succeeded"
#     },
#     "CreationTime": "2024-06-30 15:45:22.470000+00:00",
#     "GenerateCandidateDefinitionsOnly": false,
#     "InputDataConfig": [
#         {
#             "ChannelType": "training",
#             "ContentType": "text/csv;header=present",
#             "DataSource": {
#                 "S3DataSource": {
#                     "S3DataType": "S3Prefix",
#                     "S3Uri": "s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv"
#                 }
#             },
#             "TargetAttributeName": "star_rating"
#         }
#     ],
#     "LastModifiedTime": "2024-06-30 16:15:29.703000+00:00",
#     "OutputDataConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-891377026966/models/autopilot"
#     },
#     "ResolvedAttributes": {
#         "AutoMLJobObjective": {
#             "MetricName": "Accuracy"
#         },
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         },
#         "ProblemType": "MulticlassClassification"
#     },
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "5698",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 30 Jun 2024 16:16:57 GMT",
#             "x-amzn-requestid": "28a4d3be-b4e0-414e-94a9-87327adaa552"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "28a4d3be-b4e0-414e-94a9-87327adaa552",
#         "RetryAttempts": 0
#     },
#     "RoleArn": "arn:aws:iam::891377026966:role/service-role/AmazonSageMaker-ExecutionRole-20240628T190970"
# }
# CPU times: user 21.5 ms, sys: 295 µs, total: 21.8 ms
# Wall time: 191 ms

# %% [markdown]
# # [INFO] _Feel free to continue to the next workshop section while this notebook is running._

# %% [markdown]
# # Model Training and Tuning

# %% [markdown]
# ### Watch out for a SageMaker`Hyperparameter Tuning Job` and various `Training Jobs` to start.
#
# * All algorithms are optimized using a SageMaker Hyperparameter Tuning job.
# * Up to 250 training jobs (based on number of candidates specified) are selectively executed to find the best candidate model.
#
# <img src="img/autopilot-steps.png" width="90%" align="left">

# %% [markdown]
# **Autopilot Research Paper:
# https://assets.amazon.science/e8/8b/2366b1ab407990dec96e55ee5664/amazon-sagemaker-autopilot-a-white-box-automl-solution-at-scale.pdf**

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/hyper-tuning-jobs/">Hyperparameter Tuning Jobs</a></b>'.format(
            region
        )
    )
)
# Out:
# /tmp/ipykernel_270/1044137300.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/hyper-tuning-jobs/">Hyperparameter Tuning Jobs</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/jobs/">Training Jobs</a></b>'.format(
            region
        )
    )
)
# Out:
# /tmp/ipykernel_270/3328794605.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs/">Training Jobs</a></b>

# %% [markdown]
# # The Next Cell Will Show `InProgress` For A Few Minutes.
#
# ## _Please be patient._

# %%
# %%time

job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_status = job_description_response["AutoMLJobStatus"]
job_sec_status = job_description_response["AutoMLJobSecondaryStatus"]
print(job_status)
print(job_sec_status)
if job_status not in ("Stopped", "Failed"):
    while job_status in ("InProgress") and job_sec_status in ("ModelTuning"):
        job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job_description_response["AutoMLJobStatus"]
        job_sec_status = job_description_response["AutoMLJobSecondaryStatus"]
        print(job_status, job_sec_status)
        sleep(15)
    print("[OK] Model tuning phase completed.\n")

print(json.dumps(job_description_response, indent=4, sort_keys=True, default=str))
# Out:
# InProgress
# MergingAutoMLTaskReports
# [OK] Model tuning phase completed.
#
# {
#     "AutoMLJobArn": "arn:aws:sagemaker:us-east-1:891377026966:automl-job/automl-dm-30-15-44-36",
#     "AutoMLJobArtifacts": {
#         "CandidateDefinitionNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb",
#         "DataExplorationNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb"
#     },
#     "AutoMLJobConfig": {
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         }
#     },
#     "AutoMLJobName": "automl-dm-30-15-44-36",
#     "AutoMLJobSecondaryStatus": "MergingAutoMLTaskReports",
#     "AutoMLJobStatus": "InProgress",
#     "BestCandidate": {
#         "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#         "CandidateProperties": {
#             "CandidateMetrics": [
#                 {
#                     "MetricName": "F1macro",
#                     "Set": "Validation",
#                     "StandardMetricName": "F1macro",
#                     "Value": 0.45320001244544983
#                 },
#                 {
#                     "MetricName": "PrecisionMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "PrecisionMacro",
#                     "Value": 0.4521999955177307
#                 },
#                 {
#                     "MetricName": "Accuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "Accuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "BalancedAccuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "BalancedAccuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "LogLoss",
#                     "Set": "Validation",
#                     "StandardMetricName": "LogLoss",
#                     "Value": 1.2926299571990967
#                 },
#                 {
#                     "MetricName": "RecallMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "RecallMacro",
#                     "Value": 0.45486000180244446
#                 }
#             ]
#         },
#         "CandidateStatus": "Completed",
#         "CandidateSteps": [
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepType": "AWS::SageMaker::TransformJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             }
#         ],
#         "CreationTime": "2024-06-30 16:03:37+00:00",
#         "EndTime": "2024-06-30 16:07:17+00:00",
#         "FinalAutoMLJobObjectiveMetric": {
#             "MetricName": "validation:accuracy",
#             "StandardMetricName": "Accuracy",
#             "Value": 0.45486000180244446
#         },
#         "InferenceContainers": [
#             {
#                 "Environment": {
#                     "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                     "AUTOML_TRANSFORM_MODE": "feature-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "MAX_CONTENT_LENGTH": "20971520",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             }
#         ],
#         "LastModifiedTime": "2024-06-30 16:15:28.633000+00:00",
#         "ObjectiveStatus": "Succeeded"
#     },
#     "CreationTime": "2024-06-30 15:45:22.470000+00:00",
#     "GenerateCandidateDefinitionsOnly": false,
#     "InputDataConfig": [
#         {
#             "ChannelType": "training",
#             "ContentType": "text/csv;header=present",
#             "DataSource": {
#                 "S3DataSource": {
#                     "S3DataType": "S3Prefix",
#                     "S3Uri": "s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv"
#                 }
#             },
#             "TargetAttributeName": "star_rating"
#         }
#     ],
#     "LastModifiedTime": "2024-06-30 16:15:29.703000+00:00",
#     "OutputDataConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-891377026966/models/autopilot"
#     },
#     "ResolvedAttributes": {
#         "AutoMLJobObjective": {
#             "MetricName": "Accuracy"
#         },
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         },
#         "ProblemType": "MulticlassClassification"
#     },
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "5698",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 30 Jun 2024 16:18:04 GMT",
#             "x-amzn-requestid": "dcca9842-d820-4637-91ce-8474a5a71216"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "dcca9842-d820-4637-91ce-8474a5a71216",
#         "RetryAttempts": 0
#     },
#     "RoleArn": "arn:aws:iam::891377026966:role/service-role/AmazonSageMaker-ExecutionRole-20240628T190970"
# }
# CPU times: user 11.1 ms, sys: 7 ms, total: 18.2 ms
# Wall time: 116 ms

# %% [markdown]
# # _Please Wait Until ^^ Autopilot ^^ Completes Above_
#
# # [INFO] _Feel free to continue to the next workshop section while this notebook is running._

# %% [markdown]
# Make sure the status below indicates `Completed`.

# %%
# %%time

job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_status = job_description_response["AutoMLJobStatus"]
print(job_status)
if job_status not in ("Stopped", "Failed"):
    while job_status not in ("Completed"):
        job_description_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
        job_status = job_description_response["AutoMLJobStatus"]
        print(job_status)
        sleep(10)
    print("[OK] Autopilot Job completed.\n")
else:
    print(job_status)
# Out:
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# Completed
# [OK] Autopilot Job completed.
#
# CPU times: user 146 ms, sys: 29.2 ms, total: 175 ms
# Wall time: 5min 32s

# %% [markdown]
# # Viewing All Candidates
# Once model tuning is complete, you can view all the candidates (pipeline evaluations with different hyperparameter combinations) that were explored by AutoML and sort them by their final performance metric.

# %%
candidates_response = sm.list_candidates_for_auto_ml_job(
    AutoMLJobName=auto_ml_job_name, SortBy="FinalObjectiveMetricValue"
)

# %% [markdown]
# ### Check that candidates exist

# %%
print(candidates_response.keys())
# Out:
# dict_keys(['Candidates', 'ResponseMetadata'])

# %%
while "Candidates" not in candidates_response.keys():
    candidates_response = sm.list_candidates_for_auto_ml_job(
        AutoMLJobName=auto_ml_job_name, SortBy="FinalObjectiveMetricValue"
    )
    print("[INFO] Autopilot Job is generating the Candidates. Please wait.")
    print(json.dumps(candidates_response, indent=4, sort_keys=True, default=str))
    sleep(10)

candidates = candidates_response["Candidates"]
print("[OK] Candidates generated.")
# Out:
# [OK] Candidates generated.

# %%
print(candidates[0].keys())
# Out:
# dict_keys(['CandidateName', 'FinalAutoMLJobObjectiveMetric', 'ObjectiveStatus', 'CandidateSteps', 'CandidateStatus', 'InferenceContainers', 'CreationTime', 'EndTime', 'LastModifiedTime', 'CandidateProperties'])

# %%
while "CandidateName" not in candidates[0]:
    candidates_response = sm.list_candidates_for_auto_ml_job(
        AutoMLJobName=auto_ml_job_name, SortBy="FinalObjectiveMetricValue"
    )
    candidates = candidates_response["Candidates"]
    print("[INFO] Autopilot Job is generating CandidateName. Please wait. ")
    print(json.dumps(candidates, indent=4, sort_keys=True, default=str))
    sleep(10)

print("[OK] CandidateName generated.")
# Out:
# [OK] CandidateName generated.

# %%
while "FinalAutoMLJobObjectiveMetric" not in candidates[0]:
    candidates_response = sm.list_candidates_for_auto_ml_job(
        AutoMLJobName=auto_ml_job_name, SortBy="FinalObjectiveMetricValue"
    )
    candidates = candidates_response["Candidates"]
    print("[INFO] Autopilot Job is generating FinalAutoMLJobObjectiveMetric. Please wait. ")
    print(json.dumps(candidates, indent=4, sort_keys=True, default=str))
    sleep(10)

print("[OK] FinalAutoMLJobObjectiveMetric generated.")
# Out:
# [OK] FinalAutoMLJobObjectiveMetric generated.

# %%
print(json.dumps(candidates, indent=4, sort_keys=True, default=str))
# Out:
# [
#     {
#         "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#         "CandidateProperties": {
#             "CandidateArtifactLocations": {
#                 "Explainability": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/explainability/output",
#                 "ModelInsights": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/model_monitor/output"
#             },
#             "CandidateMetrics": [
#                 {
#                     "MetricName": "F1macro",
#                     "Set": "Validation",
#                     "StandardMetricName": "F1macro",
#                     "Value": 0.45320001244544983
#                 },
#                 {
#                     "MetricName": "PrecisionMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "PrecisionMacro",
#                     "Value": 0.4521999955177307
#                 },
#                 {
#                     "MetricName": "Accuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "Accuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "BalancedAccuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "BalancedAccuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "LogLoss",
#                     "Set": "Validation",
#                     "StandardMetricName": "LogLoss",
#                     "Value": 1.2926299571990967
#                 },
#                 {
#                     "MetricName": "RecallMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "RecallMacro",
#                     "Value": 0.45486000180244446
#                 }
#             ]
#         },
#         "CandidateStatus": "Completed",
#         "CandidateSteps": [
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepType": "AWS::SageMaker::TransformJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             }
#         ],
#         "CreationTime": "2024-06-30 16:03:37+00:00",
#         "EndTime": "2024-06-30 16:07:17+00:00",
#         "FinalAutoMLJobObjectiveMetric": {
#             "MetricName": "validation:accuracy",
#             "StandardMetricName": "Accuracy",
#             "Value": 0.45486000180244446
#         },
#         "InferenceContainers": [
#             {
#                 "Environment": {
#                     "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                     "AUTOML_TRANSFORM_MODE": "feature-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "MAX_CONTENT_LENGTH": "20971520",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             }
#         ],
#         "LastModifiedTime": "2024-06-30 16:15:28.633000+00:00",
#         "ObjectiveStatus": "Succeeded"
#     },
#     {
#         "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05",
#         "CandidateProperties": {
#             "CandidateMetrics": [
#                 {
#                     "MetricName": "F1macro",
#                     "Set": "Validation",
#                     "StandardMetricName": "F1macro",
#                     "Value": 0.36090001463890076
#                 },
#                 {
#                     "MetricName": "PrecisionMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "PrecisionMacro",
#                     "Value": 0.38457000255584717
#                 },
#                 {
#                     "MetricName": "Accuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "Accuracy",
#                     "Value": 0.37523001432418823
#                 },
#                 {
#                     "MetricName": "BalancedAccuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "BalancedAccuracy",
#                     "Value": 0.37523001432418823
#                 },
#                 {
#                     "MetricName": "LogLoss",
#                     "Set": "Validation",
#                     "StandardMetricName": "LogLoss",
#                     "Value": 1.5040700435638428
#                 },
#                 {
#                     "MetricName": "RecallMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "RecallMacro",
#                     "Value": 0.37523001432418823
#                 }
#             ]
#         },
#         "CandidateStatus": "Completed",
#         "CandidateSteps": [
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepType": "AWS::SageMaker::TransformJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05",
#                 "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             }
#         ],
#         "CreationTime": "2024-06-30 16:03:39+00:00",
#         "EndTime": "2024-06-30 16:11:24+00:00",
#         "FinalAutoMLJobObjectiveMetric": {
#             "MetricName": "validation:accuracy",
#             "StandardMetricName": "Accuracy",
#             "Value": 0.37523001432418823
#         },
#         "InferenceContainers": [
#             {
#                 "Environment": {
#                     "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                     "AUTOML_TRANSFORM_MODE": "feature-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "MAX_CONTENT_LENGTH": "20971520",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             }
#         ],
#         "LastModifiedTime": "2024-06-30 16:15:28.551000+00:00",
#         "ObjectiveStatus": "Succeeded"
#     },
#     {
#         "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4",
#         "CandidateProperties": {
#             "CandidateMetrics": [
#                 {
#                     "MetricName": "F1macro",
#                     "Set": "Validation",
#                     "StandardMetricName": "F1macro",
#                     "Value": 0.33719000220298767
#                 },
#                 {
#                     "MetricName": "PrecisionMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "PrecisionMacro",
#                     "Value": 0.37316998839378357
#                 },
#                 {
#                     "MetricName": "Accuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "Accuracy",
#                     "Value": 0.3558500111103058
#                 },
#                 {
#                     "MetricName": "BalancedAccuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "BalancedAccuracy",
#                     "Value": 0.3558399975299835
#                 },
#                 {
#                     "MetricName": "LogLoss",
#                     "Set": "Validation",
#                     "StandardMetricName": "LogLoss",
#                     "Value": 1.5366699695587158
#                 },
#                 {
#                     "MetricName": "RecallMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "RecallMacro",
#                     "Value": 0.3558399975299835
#                 }
#             ]
#         },
#         "CandidateStatus": "Completed",
#         "CandidateSteps": [
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepType": "AWS::SageMaker::TransformJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4",
#                 "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             }
#         ],
#         "CreationTime": "2024-06-30 16:03:45+00:00",
#         "EndTime": "2024-06-30 16:13:41+00:00",
#         "FinalAutoMLJobObjectiveMetric": {
#             "MetricName": "validation:accuracy",
#             "StandardMetricName": "Accuracy",
#             "Value": 0.3558500111103058
#         },
#         "InferenceContainers": [
#             {
#                 "Environment": {
#                     "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                     "AUTOML_TRANSFORM_MODE": "feature-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "MAX_CONTENT_LENGTH": "20971520",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             }
#         ],
#         "LastModifiedTime": "2024-06-30 16:15:28.551000+00:00",
#         "ObjectiveStatus": "Succeeded"
#     }
# ]

# %%
for index, candidate in enumerate(candidates):
    print(
        str(index)
        + "  "
        + candidate["CandidateName"]
        + "  "
        + str(candidate["FinalAutoMLJobObjectiveMetric"]["Value"])
    )
# Out:
# 0  automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2  0.45486000180244446
# 1  automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05  0.37523001432418823
# 2  automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4  0.3558500111103058

# %% [markdown]
# # Inspect Trials using Experiments API
#
# SageMaker Autopilot automatically creates a new experiment, and pushes information for each trial.

# %%
from sagemaker.analytics import ExperimentAnalytics, TrainingJobAnalytics

exp = ExperimentAnalytics(
    sagemaker_session=sess,
    experiment_name=auto_ml_job_name + "-aws-auto-ml-job",
)

df = exp.dataframe()
print(df)
# Out:
#                                   TrialComponentName  \
# 0  automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4-...
# 1  automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05-...
# 2  automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2-...
# 3  automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014...
# 4  automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b...
# 5  automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a69...
#
#                                          DisplayName  \
# 0  automl-dm-30-15-44-36MI2XQepX6ex-002-f8ffebb4-...
# 1  automl-dm-30-15-44-36MI2XQepX6ex-001-0863de05-...
# 2  automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2-...
# 3  automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014...
# 4  automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b...
# 5  automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a69...
#
#                                            SourceArn  \
# 0  arn:aws:sagemaker:us-east-1:891377026966:train...
# 1  arn:aws:sagemaker:us-east-1:891377026966:train...
# 2  arn:aws:sagemaker:us-east-1:891377026966:train...
# 3  arn:aws:sagemaker:us-east-1:891377026966:trans...
# 4  arn:aws:sagemaker:us-east-1:891377026966:train...
# 5  arn:aws:sagemaker:us-east-1:891377026966:proce...
#
#                                   SageMaker.ImageUri  SageMaker.InstanceCount  \
# 0  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 1  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 2  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 3                                                NaN                      1.0
# 4  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 5                                                NaN                      1.0
#
#   SageMaker.InstanceType  SageMaker.VolumeSizeInGB  _kfold  \
# 0         ml.m5.12xlarge                      50.0     5.0
# 1         ml.m5.12xlarge                      50.0     5.0
# 2         ml.m5.12xlarge                      50.0     5.0
# 3          ml.m5.4xlarge                       NaN     NaN
# 4         ml.m5.12xlarge                      50.0     NaN
# 5          ml.m5.2xlarge                     250.0     NaN
#
#   _tuning_objective_metric     alpha  ...  enable_validation_split  \
# 0      validation:accuracy  0.000003  ...                      NaN
# 1      validation:accuracy  0.000181  ...                      NaN
# 2      validation:accuracy  0.005604  ...                      NaN
# 3                      NaN       NaN  ...                      NaN
# 4                      NaN       NaN  ...                      NaN
# 5                      NaN       NaN  ...                     true
#
#    input_channel_mode               job_name    label_col  max_dataset_size  \
# 0                 NaN                    NaN          NaN               NaN
# 1                 NaN                    NaN          NaN               NaN
# 2                 NaN                    NaN          NaN               NaN
# 3                 NaN                    NaN          NaN               NaN
# 4                 NaN                    NaN          NaN               NaN
# 5                Pipe  automl-dm-30-15-44-36  star_rating               100
#
#    max_subsampled_dataset_size  SageMaker.ImageUri - MediaType  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# 5                            5                             NaN
#
#                           SageMaker.ImageUri - Value  ds - MediaType  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5  120479346908.dkr.ecr.us-east-1.amazonaws.com/d...             NaN
#
#                                           ds - Value
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  s3://sagemaker-us-east-1-891377026966/models/a...
#
# [6 rows x 126 columns]

# %% [markdown]
# # Explore the Best Candidate
# Now that we have successfully completed the AutoML job on our dataset and visualized the trials, we can create a model from any of the trials with a single API call and then deploy that model for online or batch prediction using [Inference Pipelines](https://docs.aws.amazon.com/sagemaker/latest/dg/inference-pipelines.html). For this notebook, we deploy only the best performing trial for inference.

# %% [markdown]
# The best candidate is the one we're really interested in.

# %%
best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)

# %%
print(best_candidate_response.keys())
# Out:
# dict_keys(['AutoMLJobName', 'AutoMLJobArn', 'InputDataConfig', 'OutputDataConfig', 'RoleArn', 'AutoMLJobConfig', 'CreationTime', 'EndTime', 'LastModifiedTime', 'BestCandidate', 'AutoMLJobStatus', 'AutoMLJobSecondaryStatus', 'GenerateCandidateDefinitionsOnly', 'AutoMLJobArtifacts', 'ResolvedAttributes', 'ResponseMetadata'])

# %%
while "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    print("[INFO] Autopilot Job is generating BestCandidate. Please wait. ")
    print(json.dumps(best_candidate_response, indent=4, sort_keys=True, default=str))
    sleep(10)

best_candidate = best_candidate_response["BestCandidate"]
print("[OK] BestCandidate generated.")
# Out:
# [OK] BestCandidate generated.

# %%
print(json.dumps(best_candidate_response, indent=4, sort_keys=True, default=str))
# Out:
# {
#     "AutoMLJobArn": "arn:aws:sagemaker:us-east-1:891377026966:automl-job/automl-dm-30-15-44-36",
#     "AutoMLJobArtifacts": {
#         "CandidateDefinitionNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb",
#         "DataExplorationNotebookLocation": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/sagemaker-automl-candidates/automl-dm-30-15-44-36-pr-1-d6bbf9cc96914a92b2e039d5bc64632aa872/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb"
#     },
#     "AutoMLJobConfig": {
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         }
#     },
#     "AutoMLJobName": "automl-dm-30-15-44-36",
#     "AutoMLJobSecondaryStatus": "Completed",
#     "AutoMLJobStatus": "Completed",
#     "BestCandidate": {
#         "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#         "CandidateProperties": {
#             "CandidateArtifactLocations": {
#                 "Explainability": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/explainability/output",
#                 "ModelInsights": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/model_monitor/output"
#             },
#             "CandidateMetrics": [
#                 {
#                     "MetricName": "F1macro",
#                     "Set": "Validation",
#                     "StandardMetricName": "F1macro",
#                     "Value": 0.45320001244544983
#                 },
#                 {
#                     "MetricName": "PrecisionMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "PrecisionMacro",
#                     "Value": 0.4521999955177307
#                 },
#                 {
#                     "MetricName": "Accuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "Accuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "BalancedAccuracy",
#                     "Set": "Validation",
#                     "StandardMetricName": "BalancedAccuracy",
#                     "Value": 0.45486000180244446
#                 },
#                 {
#                     "MetricName": "LogLoss",
#                     "Set": "Validation",
#                     "StandardMetricName": "LogLoss",
#                     "Value": 1.2926299571990967
#                 },
#                 {
#                     "MetricName": "RecallMacro",
#                     "Set": "Validation",
#                     "StandardMetricName": "RecallMacro",
#                     "Value": 0.45486000180244446
#                 }
#             ]
#         },
#         "CandidateStatus": "Completed",
#         "CandidateSteps": [
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#                 "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#                 "CandidateStepType": "AWS::SageMaker::TransformJob"
#             },
#             {
#                 "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#                 "CandidateStepType": "AWS::SageMaker::TrainingJob"
#             }
#         ],
#         "CreationTime": "2024-06-30 16:03:37+00:00",
#         "EndTime": "2024-06-30 16:07:17+00:00",
#         "FinalAutoMLJobObjectiveMetric": {
#             "MetricName": "validation:accuracy",
#             "StandardMetricName": "Accuracy",
#             "Value": 0.45486000180244446
#         },
#         "InferenceContainers": [
#             {
#                 "Environment": {
#                     "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                     "AUTOML_TRANSFORM_MODE": "feature-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "MAX_CONTENT_LENGTH": "20971520",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz"
#             },
#             {
#                 "Environment": {
#                     "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                     "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                     "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                     "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                     "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                     "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#                 },
#                 "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#                 "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#             }
#         ],
#         "LastModifiedTime": "2024-06-30 16:15:28.633000+00:00",
#         "ObjectiveStatus": "Succeeded"
#     },
#     "CreationTime": "2024-06-30 15:45:22.470000+00:00",
#     "EndTime": "2024-06-30 16:23:45.889000+00:00",
#     "GenerateCandidateDefinitionsOnly": false,
#     "InputDataConfig": [
#         {
#             "ChannelType": "training",
#             "ContentType": "text/csv;header=present",
#             "DataSource": {
#                 "S3DataSource": {
#                     "S3DataType": "S3Prefix",
#                     "S3Uri": "s3://sagemaker-us-east-1-891377026966/data/amazon_reviews_us_Digital_Software_v1_00_autopilot.csv"
#                 }
#             },
#             "TargetAttributeName": "star_rating"
#         }
#     ],
#     "LastModifiedTime": "2024-06-30 16:23:45.931000+00:00",
#     "OutputDataConfig": {
#         "S3OutputPath": "s3://sagemaker-us-east-1-891377026966/models/autopilot"
#     },
#     "ResolvedAttributes": {
#         "AutoMLJobObjective": {
#             "MetricName": "Accuracy"
#         },
#         "CompletionCriteria": {
#             "MaxAutoMLJobRuntimeInSeconds": 5400,
#             "MaxCandidates": 3,
#             "MaxRuntimePerTrainingJobInSeconds": 900
#         },
#         "ProblemType": "MulticlassClassification"
#     },
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "6002",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 30 Jun 2024 16:26:56 GMT",
#             "x-amzn-requestid": "cb45dec1-3922-4769-a7fa-87b710dec160"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "cb45dec1-3922-4769-a7fa-87b710dec160",
#         "RetryAttempts": 0
#     },
#     "RoleArn": "arn:aws:iam::891377026966:role/service-role/AmazonSageMaker-ExecutionRole-20240628T190970"
# }

# %%
print(best_candidate.keys())
# Out:
# dict_keys(['CandidateName', 'FinalAutoMLJobObjectiveMetric', 'ObjectiveStatus', 'CandidateSteps', 'CandidateStatus', 'InferenceContainers', 'CreationTime', 'EndTime', 'LastModifiedTime', 'CandidateProperties'])

# %%
# Doing BestCandidate check again because of Github issue https://github.com/data-science-on-aws/data-science-on-aws/issues/107
while "CandidateName" not in best_candidate and "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    best_candidate = best_candidate_response["BestCandidate"]
    print("[INFO] Autopilot Job is generating BestCandidate CandidateName. Please wait. ")
    print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
    sleep(10)

print("[OK] BestCandidate CandidateName generated.")
# Out:
# [OK] BestCandidate CandidateName generated.

# %%
# Doing BestCandidate check again because of Github issue https://github.com/data-science-on-aws/data-science-on-aws/issues/107
while "FinalAutoMLJobObjectiveMetric" not in best_candidate and "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    best_candidate = best_candidate_response["BestCandidate"]
    print("[INFO] Autopilot Job is generating BestCandidate FinalAutoMLJobObjectiveMetric. Please wait. ")
    print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
    sleep(10)

print("[OK] BestCandidate FinalAutoMLJobObjectiveMetric generated.")
# Out:
# [OK] BestCandidate FinalAutoMLJobObjectiveMetric generated.

# %%
best_candidate_identifier = best_candidate["CandidateName"]
print("Candidate name: " + best_candidate_identifier)
print("Metric name: " + best_candidate["FinalAutoMLJobObjectiveMetric"]["MetricName"])
print("Metric value: " + str(best_candidate["FinalAutoMLJobObjectiveMetric"]["Value"]))
# Out:
# Candidate name: automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2
# Metric name: validation:accuracy
# Metric value: 0.45486000180244446

# %%
print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
# Out:
# {
#     "CandidateName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#     "CandidateProperties": {
#         "CandidateArtifactLocations": {
#             "Explainability": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/explainability/output",
#             "ModelInsights": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/model_monitor/output"
#         },
#         "CandidateMetrics": [
#             {
#                 "MetricName": "F1macro",
#                 "Set": "Validation",
#                 "StandardMetricName": "F1macro",
#                 "Value": 0.45320001244544983
#             },
#             {
#                 "MetricName": "PrecisionMacro",
#                 "Set": "Validation",
#                 "StandardMetricName": "PrecisionMacro",
#                 "Value": 0.4521999955177307
#             },
#             {
#                 "MetricName": "Accuracy",
#                 "Set": "Validation",
#                 "StandardMetricName": "Accuracy",
#                 "Value": 0.45486000180244446
#             },
#             {
#                 "MetricName": "BalancedAccuracy",
#                 "Set": "Validation",
#                 "StandardMetricName": "BalancedAccuracy",
#                 "Value": 0.45486000180244446
#             },
#             {
#                 "MetricName": "LogLoss",
#                 "Set": "Validation",
#                 "StandardMetricName": "LogLoss",
#                 "Value": 1.2926299571990967
#             },
#             {
#                 "MetricName": "RecallMacro",
#                 "Set": "Validation",
#                 "StandardMetricName": "RecallMacro",
#                 "Value": 0.45486000180244446
#             }
#         ]
#     },
#     "CandidateStatus": "Completed",
#     "CandidateSteps": [
#         {
#             "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#             "CandidateStepName": "automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c",
#             "CandidateStepType": "AWS::SageMaker::ProcessingJob"
#         },
#         {
#             "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#             "CandidateStepName": "automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380",
#             "CandidateStepType": "AWS::SageMaker::TrainingJob"
#         },
#         {
#             "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#             "CandidateStepName": "automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf",
#             "CandidateStepType": "AWS::SageMaker::TransformJob"
#         },
#         {
#             "CandidateStepArn": "arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#             "CandidateStepName": "automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2",
#             "CandidateStepType": "AWS::SageMaker::TrainingJob"
#         }
#     ],
#     "CreationTime": "2024-06-30 16:03:37+00:00",
#     "EndTime": "2024-06-30 16:07:17+00:00",
#     "FinalAutoMLJobObjectiveMetric": {
#         "MetricName": "validation:accuracy",
#         "StandardMetricName": "Accuracy",
#         "Value": 0.45486000180244446
#     },
#     "InferenceContainers": [
#         {
#             "Environment": {
#                 "AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF": "1",
#                 "AUTOML_TRANSFORM_MODE": "feature-transform",
#                 "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "application/x-recordio-protobuf",
#                 "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                 "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#             },
#             "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#             "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#         },
#         {
#             "Environment": {
#                 "MAX_CONTENT_LENGTH": "20971520",
#                 "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                 "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                 "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,probabilities"
#             },
#             "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3",
#             "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz"
#         },
#         {
#             "Environment": {
#                 "AUTOML_TRANSFORM_MODE": "inverse-label-transform",
#                 "SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT": "text/csv",
#                 "SAGEMAKER_INFERENCE_INPUT": "predicted_label",
#                 "SAGEMAKER_INFERENCE_OUTPUT": "predicted_label",
#                 "SAGEMAKER_INFERENCE_SUPPORTED": "predicted_label,probability,labels,probabilities",
#                 "SAGEMAKER_PROGRAM": "sagemaker_serve",
#                 "SAGEMAKER_SUBMIT_DIRECTORY": "/opt/ml/model/code"
#             },
#             "Image": "683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3",
#             "ModelDataUrl": "s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz"
#         }
#     ],
#     "LastModifiedTime": "2024-06-30 16:15:28.633000+00:00",
#     "ObjectiveStatus": "Succeeded"
# }

# %% [markdown]
# # View Individual Autopilot Jobs

# %%
# Doing BestCandidate check again because of Github issue https://github.com/data-science-on-aws/data-science-on-aws/issues/107
while "CandidateSteps" not in best_candidate and "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    best_candidate = best_candidate_response["BestCandidate"]
    print("[INFO] Autopilot Job is generating BestCandidate CandidateSteps. Please wait. ")
    print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
    sleep(10)

best_candidate = best_candidate_response["BestCandidate"]
print("[OK] BestCandidate CandidateSteps generated.")
# Out:
# [OK] BestCandidate CandidateSteps generated.

# %%
# Doing BestCandidate check again because of Github issue https://github.com/data-science-on-aws/data-science-on-aws/issues/107
while "CandidateStepType" not in best_candidate["CandidateSteps"][0] and "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    best_candidate = best_candidate_response["BestCandidate"]
    print("[INFO] Autopilot Job is generating BestCandidate CandidateSteps CandidateStepType. Please wait. ")
    print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
    sleep(10)

best_candidate = best_candidate_response["BestCandidate"]
print("[OK] BestCandidate CandidateSteps CandidateStepType generated.")
# Out:
# [OK] BestCandidate CandidateSteps CandidateStepType generated.

# %%
# Doing BestCandidate check again because of Github issue https://github.com/data-science-on-aws/data-science-on-aws/issues/107
while "CandidateStepName" not in best_candidate["CandidateSteps"][0] and "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    best_candidate = best_candidate_response["BestCandidate"]
    print("[INFO] Autopilot Job is generating BestCandidate CandidateSteps CandidateStepName. Please wait. ")
    print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
    sleep(10)

best_candidate = best_candidate_response["BestCandidate"]
print("[OK] BestCandidate CandidateSteps CandidateStepName generated.")
# Out:
# [OK] BestCandidate CandidateSteps CandidateStepName generated.

# %%
best_candidate
# Out:
# {'CandidateName': 'automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2',
#  'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#   'Value': 0.45486000180244446,
#   'StandardMetricName': 'Accuracy'},
#  'ObjectiveStatus': 'Succeeded',
#  'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:891377026966:processing-job/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c',
#    'CandidateStepName': 'automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c'},
#   {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380',
#    'CandidateStepName': 'automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380'},
#   {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:891377026966:transform-job/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf',
#    'CandidateStepName': 'automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf'},
#   {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#    'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:891377026966:training-job/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2',
#    'CandidateStepName': 'automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2'}],
#  'CandidateStatus': 'Completed',
#  'InferenceContainers': [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3',
#    'ModelDataUrl': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz',
#    'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#     'AUTOML_TRANSFORM_MODE': 'feature-transform',
#     'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#     'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#     'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}},
#   {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3',
#    'ModelDataUrl': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz',
#    'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#     'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#     'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#     'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#   {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3',
#    'ModelDataUrl': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz',
#    'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#     'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#     'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#     'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#     'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#     'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#     'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}],
#  'CreationTime': datetime.datetime(2024, 6, 30, 16, 3, 37, tzinfo=tzlocal()),
#  'EndTime': datetime.datetime(2024, 6, 30, 16, 7, 17, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2024, 6, 30, 16, 15, 28, 633000, tzinfo=tzlocal()),
#  'CandidateProperties': {'CandidateArtifactLocations': {'Explainability': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/explainability/output',
#    'ModelInsights': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/documentation/model_monitor/output'},
#   'CandidateMetrics': [{'MetricName': 'F1macro',
#     'Value': 0.45320001244544983,
#     'Set': 'Validation',
#     'StandardMetricName': 'F1macro'},
#    {'MetricName': 'PrecisionMacro',
#     'Value': 0.4521999955177307,
#     'Set': 'Validation',
#     'StandardMetricName': 'PrecisionMacro'},
#    {'MetricName': 'Accuracy',
#     'Value': 0.45486000180244446,
#     'Set': 'Validation',
#     'StandardMetricName': 'Accuracy'},
#    {'MetricName': 'BalancedAccuracy',
#     'Value': 0.45486000180244446,
#     'Set': 'Validation',
#     'StandardMetricName': 'BalancedAccuracy'},
#    {'MetricName': 'LogLoss',
#     'Value': 1.2926299571990967,
#     'Set': 'Validation',
#     'StandardMetricName': 'LogLoss'},
#    {'MetricName': 'RecallMacro',
#     'Value': 0.45486000180244446,
#     'Set': 'Validation',
#     'StandardMetricName': 'RecallMacro'}]}}

# %%
steps = []
for step in best_candidate["CandidateSteps"]:
    print("Candidate Step Type: {}".format(step["CandidateStepType"]))
    print("Candidate Step Name: {}".format(step["CandidateStepName"]))
    steps.append(step["CandidateStepName"])
# Out:
# Candidate Step Type: AWS::SageMaker::ProcessingJob
# Candidate Step Name: automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c
# Candidate Step Type: AWS::SageMaker::TrainingJob
# Candidate Step Name: automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380
# Candidate Step Type: AWS::SageMaker::TransformJob
# Candidate Step Name: automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf
# Candidate Step Type: AWS::SageMaker::TrainingJob
# Candidate Step Name: automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/processing-jobs/{}">Processing Job</a></b>'.format(
            region, steps[0]
        )
    )
)
# Out:
# /tmp/ipykernel_270/3708483486.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/processing-jobs/automl-dm-30-15-44-36-db-1-b127166c1fbf4a53a696c2fc4e8214e80f3c">Processing Job</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/jobs/{}">Training Job</a></b>'.format(
            region, steps[1]
        )
    )
)
# Out:
# /tmp/ipykernel_270/4145761464.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380">Training Job</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/transform-jobs/{}">Transform Job</a></b>'.format(
            region, steps[2]
        )
    )
)
# Out:
# /tmp/ipykernel_270/159320059.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/transform-jobs/automl-dm-30-15-44-36-dpp0-rpb-1-bb0c2c24e4014b37b935893ef8eecf">Transform Job</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/jobs/{}">Training Job (Tuning)</a></b>'.format(
            region, steps[3]
        )
    )
)
# Out:
# /tmp/ipykernel_270/4238719445.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review Best Candidate <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2">Training Job (Tuning)</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review All <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/processing-jobs/">Processing Jobs</a></b>'.format(
            region
        )
    )
)
# Out:
# /tmp/ipykernel_270/748332249.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review All <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/processing-jobs/">Processing Jobs</a></b>

# %% [markdown]
# # Review All Output in S3
#
# You will see the artifacts generated by Autopilot including the following:
# ```
# data-processor-models/        # "models" learned to transform raw data into features
# documentation/                # explainability and other documentation about your model
# preprocessed-data/            # data for train and validation
# sagemaker-automl-candidates/  # candidate models which autopilot compares
# transformed-data/             # candidate-specific data for train and validation
# tuning/                       # candidate-specific tuning results
# validations/                  # validation results
# ```

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review All <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/{}?region={}&prefix=models/autopilot/{}/">Output in S3</a></b>'.format(
            bucket, region, auto_ml_job_name
        )
    )
)
# Out:
# /tmp/ipykernel_270/1802943313.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review All <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-891377026966?region=us-east-1&prefix=models/autopilot/automl-dm-30-15-44-36/">Output in S3</a></b>

# %% [markdown]
# # See the Containers and Models within the Inference Pipeline

# %%
# Doing BestCandidate check again because of Github issue https://github.com/data-science-on-aws/data-science-on-aws/issues/107
while "InferenceContainers" not in best_candidate and "BestCandidate" not in best_candidate_response:
    best_candidate_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    best_candidate = best_candidate_response["BestCandidate"]
    print("[INFO] Autopilot Job is generating BestCandidate InferenceContainers. Please wait. ")
    print(json.dumps(best_candidate, indent=4, sort_keys=True, default=str))
    sleep(10)

print("[OK] BestCandidate InferenceContainers generated.")
# Out:
# [OK] BestCandidate InferenceContainers generated.

# %%
best_candidate_containers = best_candidate["InferenceContainers"]

# %%
for container in best_candidate_containers:
    print(container["Image"])
    print(container["ModelDataUrl"])
    print("======================")
# Out:
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3
# s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz
# ======================
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3
# s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz
# ======================
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3
# s3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz
# ======================

# %% [markdown]
# # Update Containers To Show Predicted Label and Confidence Score

# %%
for container in best_candidate_containers:
    print(container["Environment"])
    print("======================")
# Out:
# {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1', 'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}
# ======================
# {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}
# ======================
# {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_INPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}
# ======================

# %%
best_candidate_containers[1]["Environment"].update({"SAGEMAKER_INFERENCE_OUTPUT": "predicted_label, probability"})
best_candidate_containers[2]["Environment"].update({"SAGEMAKER_INFERENCE_INPUT": "predicted_label, probability"})
best_candidate_containers[2]["Environment"].update({"SAGEMAKER_INFERENCE_OUTPUT": "predicted_label, probability"})

# %%
for container in best_candidate_containers:
    print(container["Environment"])
    print("======================")
# Out:
# {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1', 'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}
# ======================
# {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label, probability', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}
# ======================
# {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_INPUT': 'predicted_label, probability', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label, probability', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}
# ======================

# %% [markdown]
# # Autopilot Chooses XGBoost as Best Candidate!
#
# Note that Autopilot chose different hyper-parameters and feature transformations than we used in our own XGBoost model.

# %% [markdown]
# # Deploy the Model as a REST Endpoint
# Batch transformations are also supported, but for now, we will use a REST Endpoint.

# %%
print(best_candidate["InferenceContainers"])
# Out:
# [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz', 'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1', 'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/tuning/automl-dm--dpp0-xgb/automl-dm-30-15-44-36MI2XQepX6ex-003-a4b028b2/output/model.tar.gz', 'Environment': {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label, probability', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-891377026966/models/autopilot/automl-dm-30-15-44-36/data-processor-models/automl-dm-30-15-44-36-dpp0-1-75004a27c8a740c3b48313c13368e14380/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_INPUT': 'predicted_label, probability', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label, probability', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}]

# %%
# %store -r autopilot_model_name
# Out:
# no stored variable or alias autopilot_model_name

# %%
try:
    autopilot_model_name
except NameError:
    timestamp_suffix = strftime("%d-%H-%M-%S", gmtime())
    autopilot_model_name = "automl-dm-model-" + timestamp_suffix
    print("[OK] Created Autopilot Model Name: " + autopilot_model_name)
# Out:
# [OK] Created Autopilot Model Name: automl-dm-model-30-16-33-38

# %%
# %store autopilot_model_name
# Out:
# Stored 'autopilot_model_name' (str)

# %%
# %store -r autopilot_model_arn
# Out:
# no stored variable or alias autopilot_model_arn

# %%
try:
    autopilot_model_arn
except NameError:
    create_model_response = sm.create_model(
        Containers=best_candidate["InferenceContainers"], ModelName=autopilot_model_name, ExecutionRoleArn=role
    )
    autopilot_model_arn = create_model_response["ModelArn"]
    print("[OK] Created Autopilot Model: {}".format(autopilot_model_arn))
# Out:
# [OK] Created Autopilot Model: arn:aws:sagemaker:us-east-1:891377026966:model/automl-dm-model-30-16-33-38

# %%
# %store autopilot_model_arn
# Out:
# Stored 'autopilot_model_arn' (str)

# %% [markdown]
# # Define EndpointConfig Name

# %%
timestamp_suffix = strftime("%d-%H-%M-%S", gmtime())
epc_name = "automl-dm-epc-" + timestamp_suffix

print(epc_name)
# Out:
# automl-dm-epc-30-16-34-17

# %% [markdown]
# # Define REST Endpoint Name for Autopilot Model

# %%
# %store -r autopilot_endpoint_name
# Out:
# no stored variable or alias autopilot_endpoint_name

# %%
timestamp_suffix = strftime("%d-%H-%M-%S", gmtime())

try:
    autopilot_endpoint_name
except NameError:
    autopilot_endpoint_name = "automl-dm-ep-" + timestamp_suffix
    print("[OK] Created Autopilot Endpoint Name {}: ".format(autopilot_endpoint_name))
# Out:
# [OK] Created Autopilot Endpoint Name automl-dm-ep-30-16-34-32:

# %%
variant_name = "automl-dm-variant-" + timestamp_suffix
print("[OK] Created Endpoint Variant Name {}: ".format(variant_name))
# Out:
# [OK] Created Endpoint Variant Name automl-dm-variant-30-16-34-32:

# %%
# %store autopilot_endpoint_name
# Out:
# Stored 'autopilot_endpoint_name' (str)

# %%
ep_config = sm.create_endpoint_config(
    EndpointConfigName=epc_name,
    ProductionVariants=[
        {
            "InstanceType": "ml.m5.large",
            "InitialInstanceCount": 1,
            "ModelName": autopilot_model_name,
            "VariantName": variant_name,
        }
    ],
)

# %%
# %store -r autopilot_endpoint_arn
# Out:
# no stored variable or alias autopilot_endpoint_arn

# %%
try:
    autopilot_endpoint_arn
except NameError:
    create_endpoint_response = sm.create_endpoint(EndpointName=autopilot_endpoint_name, EndpointConfigName=epc_name)
    autopilot_endpoint_arn = create_endpoint_response["EndpointArn"]
    print(autopilot_endpoint_arn)
# Out:
# arn:aws:sagemaker:us-east-1:891377026966:endpoint/automl-dm-ep-30-16-34-32

# %%
# %store autopilot_endpoint_arn
# Out:
# Stored 'autopilot_endpoint_arn' (str)

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/endpoints/{}">SageMaker REST Endpoint</a></b>'.format(
            region, autopilot_endpoint_name
        )
    )
)
# Out:
# /tmp/ipykernel_270/3097833244.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/endpoints/automl-dm-ep-30-16-34-32">SageMaker REST Endpoint</a></b>

# %% [markdown]
# # Store Variables for the Next Notebooks

# %%
# %store
# Out:
# Stored variables and their in-db values:
# auto_ml_job_name                    -> 'automl-dm-30-15-44-36'
# autopilot_endpoint_arn              -> 'arn:aws:sagemaker:us-east-1:891377026966:endpoint
# autopilot_endpoint_name             -> 'automl-dm-ep-30-16-34-32'
# autopilot_model_arn                 -> 'arn:aws:sagemaker:us-east-1:891377026966:model/au
# autopilot_model_name                -> 'automl-dm-model-30-16-33-38'
# autopilot_train_s3_uri              -> 's3://sagemaker-us-east-1-891377026966/data/amazon

# %% [markdown]
# # Summary
# We used Autopilot to automatically find the best model, hyper-parameters, and feature-engineering scripts for our dataset.
#
# Autopilot uses a transparent approach to generate re-usable exploration Jupyter Notebooks and transformation Python scripts to continue to train and deploy our model on new data - well after this initial interaction with the Autopilot service.

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
