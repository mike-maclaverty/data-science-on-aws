# %% [markdown]
# # Upload Sample Images and Videos

# %%
import boto3
import sagemaker

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)

# %%
# !aws s3 cp --recursive ./media/ s3://$bucket/content-moderation/media/
# Out:
# upload: media/chris-antje.png to s3://sagemaker-us-east-1-891377026966/content-moderation/media/chris-antje.png
# upload: media/coffee.jpg to s3://sagemaker-us-east-1-891377026966/content-moderation/media/coffee.jpg
# upload: media/cars.png to s3://sagemaker-us-east-1-891377026966/content-moderation/media/cars.png
# upload: media/GrandTourjc.png to s3://sagemaker-us-east-1-891377026966/content-moderation/media/GrandTourjc.png
# upload: media/hat-detection.png to s3://sagemaker-us-east-1-891377026966/content-moderation/media/hat-detection.png
# upload: media/weapon.mp4 to s3://sagemaker-us-east-1-891377026966/content-moderation/media/weapon.mp4
# upload: media/serverless-bytes.mov to s3://sagemaker-us-east-1-891377026966/content-moderation/media/serverless-bytes.mov
# upload: media/weapon.png to s3://sagemaker-us-east-1-891377026966/content-moderation/media/weapon.png
# upload: media/GrandTour720.mp4 to s3://sagemaker-us-east-1-891377026966/content-moderation/media/GrandTour720.mp4

# %%
# !aws s3 ls s3://$bucket/content-moderation/media/
# Out:
# 2024-06-29 22:41:01    5321410 GrandTour720.mp4
# 2024-06-29 22:41:01    3453431 GrandTourjc.png
# 2024-06-29 22:41:01     998652 cars.png
# 2024-06-29 22:41:01     132849 chris-antje.png
# 2024-06-29 22:41:01     182226 coffee.jpg
# 2024-06-29 22:41:01     932907 hat-detection.png
# 2024-06-29 22:41:01    2099007 serverless-bytes.mov
# 2024-06-29 22:41:01     803874 weapon.mp4
# 2024-06-29 22:41:01    1214085 weapon.png

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
