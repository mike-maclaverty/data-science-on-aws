# %% [markdown]
# # Text detection using Amazon Rekognition

# %% [markdown]
# This notebook provides a walkthrough of the [text detection API](https://docs.aws.amazon.com/rekognition/latest/dg/text-detection.html) in Amazon Rekognition. You can quickly identify text in your video and image libraries to catalog footage and photos for marketing, advertising, and media industry use cases.

# %%
import boto3
from IPython.display import HTML, display, Image as IImage
from PIL import Image, ImageDraw, ImageFont
import time
import os

# %%
import sagemaker
import boto3

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

# %%
rekognition = boto3.client("rekognition")
s3 = boto3.client("s3")

# %%
# !mkdir -p ./tmp
temp_folder = "tmp/"

# %% [markdown]
# # Detect text in image

# %%
imageName = "content-moderation/media/coffee.jpg"

# %%
display(IImage(url=s3.generate_presigned_url("get_object", Params={"Bucket": bucket, "Key": imageName})))
# Out:
# <img src="https://sagemaker-us-east-1-891377026966.s3.amazonaws.com/content-moderation/media/coffee.jpg?AWSAccessKeyId=ASIA47CRWA6LC2RIUL7N&Signature=VE6d94nKxs1Rn4ZpMhgcTvu0scY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEH8aCXVzLWVhc3QtMSJHMEUCIQCa3stryoP8OMiRGUjjwICsqsv25tKNYUwabCERds6CiAIgBx7XkUgvTS2yIFSTfpK0CCPyv7Q2p%2B74xbIpBzxn93AqswMIOBAAGgw4OTEzNzcwMjY5NjYiDDpV%2FSxgnsgRMMHntyqQAwc9J5VpM9nHU3WZk91COh11V31LYX%2FRp109Tvi02Xf%2BximPnId3TTi5nYNne7yZMUEWxUPNrdtNkgthvXUJdfCeU1Yw7ku8jq7nGoEQ5bvB6EoDeh5CrfUXSMYuL6295YZzZ893dmF4rRSz%2ByZqFn8GMDqnc62PDaSE2WyCO5t8JSItne1DzDGj3lyWQamlg0U4Mm21CZKEHIKu29l9PEs6SHdHMCux98RDXDaBTFM5U76vGoQr64EPX5%2F7KW868rWQhfIUqAe1JKhElYeeDyCROQyS7osFYfnD79nY4YrGlJ8XPDeelKUmYQcns5YKaSdPKS18EtW7lYKRcLtmhyD6T9pUuQ0YW7tZJuYxmuYcuAf36aGm0AZVfU7fL8C5dO4CjI6TjH6rdpCDC6lEK2WpKwUNdk9W7kfH0E2b3bblQHhUR5qAkyoGjOLMpewAxdGKRB7UiBVBnLIsj7s4%2FQHR%2FCoJmVptc50q4%2FVvqK5HxjXQg0w%2BYdjkCpXuCphy6wEH4gJbLxgiDisX7FIkCGQw1pqCtAY6ngGGsXMj1Z%2FLN8eixwxNLloXIXnpR3GAu4yvijndLY%2FKIMEaGPJOZvMkZ7hvWrIFxc0tIIr9jLPcXthYYOKR7WbPC0W7FOZ7d%2Byku8rtTDGMVcAzQxHKLvCTX%2BkEKkV04YTqW%2BqhiRZVjOi%2BCEZ3sR1BMui5VMmmSMMJ%2Banjd5cnVpemXVis8OskEWrzsKI86yn5aWB7L%2B8XW6GQggVbag%3D%3D&Expires=1719704854"/>

# %% [markdown]
# # Call Rekognition to Detect Text in the Image
# https://docs.aws.amazon.com/rekognition/latest/dg/API_DetectText.html

# %%
detectTextResponse = rekognition.detect_text(
    Image={
        "S3Object": {
            "Bucket": bucket,
            "Name": imageName,
        }
    },
    Filters={"WordFilter": {"MinConfidence": 90}},
)

# %% [markdown]
# # Review the raw JSON reponse from Rekognition
# In the JSON response below, you will see detected text, confidence score, and additional information.

# %%
display(detectTextResponse)
# Out:
# {'TextDetections': [{'DetectedText': 'damm it',
#    'Type': 'LINE',
#    'Id': 0,
#    'Confidence': 99.98050689697266,
#    'Geometry': {'BoundingBox': {'Width': 0.1419270783662796,
#      'Height': 0.046874988824129105,
#      'Left': 0.01627604104578495,
#      'Top': 0.016601568087935448},
#     'Polygon': [{'X': 0.01627604104578495, 'Y': 0.016601568087935448},
#      {'X': 0.158203125, 'Y': 0.016601568087935448},
#      {'X': 0.158203125, 'Y': 0.0634765550494194},
#      {'X': 0.01627604104578495, 'Y': 0.0634765550494194}]}},
#   {'DetectedText': 'darn it',
#    'Type': 'LINE',
#    'Id': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.1100260391831398,
#      'Height': 0.044921875,
#      'Left': 0.0325520820915699,
#      'Top': 0.1552734375},
#     'Polygon': [{'X': 0.0325520820915699, 'Y': 0.1552734375},
#      {'X': 0.142578125, 'Y': 0.1552734375},
#      {'X': 0.142578125, 'Y': 0.2001953125},
#      {'X': 0.0325520820915699, 'Y': 0.2001953125}]}},
#   {'DetectedText': "IT'S",
#    'Type': 'LINE',
#    'Id': 2,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.13671875,
#      'Height': 0.0966796875,
#      'Left': 0.6751301884651184,
#      'Top': 0.1875},
#     'Polygon': [{'X': 0.6751301884651184, 'Y': 0.1875},
#      {'X': 0.8118489384651184, 'Y': 0.1875},
#      {'X': 0.8118489384651184, 'Y': 0.2841796875},
#      {'X': 0.6751301884651184, 'Y': 0.2841796875}]}},
#   {'DetectedText': 'crap',
#    'Type': 'LINE',
#    'Id': 3,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.076171875,
#      'Height': 0.0478515625,
#      'Left': 0.048828125,
#      'Top': 0.302734375},
#     'Polygon': [{'X': 0.048828125, 'Y': 0.302734375},
#      {'X': 0.125, 'Y': 0.302734375},
#      {'X': 0.125, 'Y': 0.3505859375},
#      {'X': 0.048828125, 'Y': 0.3505859375}]}},
#   {'DetectedText': 'MONDAY',
#    'Type': 'LINE',
#    'Id': 4,
#    'Confidence': 99.38906860351562,
#    'Geometry': {'BoundingBox': {'Width': 0.3971354067325592,
#      'Height': 0.1142578125,
#      'Left': 0.5540364384651184,
#      'Top': 0.3544921875},
#     'Polygon': [{'X': 0.5540364384651184, 'Y': 0.3544921875},
#      {'X': 0.951171875, 'Y': 0.3544921875},
#      {'X': 0.951171875, 'Y': 0.46875},
#      {'X': 0.5540364384651184, 'Y': 0.46875}]}},
#   {'DetectedText': 'but keep',
#    'Type': 'LINE',
#    'Id': 5,
#    'Confidence': 99.91482543945312,
#    'Geometry': {'BoundingBox': {'Width': 0.2024739533662796,
#      'Height': 0.080078125,
#      'Left': 0.6399739384651184,
#      'Top': 0.5283203125},
#     'Polygon': [{'X': 0.6399739384651184, 'Y': 0.5283203125},
#      {'X': 0.8424479365348816, 'Y': 0.5283203125},
#      {'X': 0.8424479365348816, 'Y': 0.6083984375},
#      {'X': 0.6399739384651184, 'Y': 0.6083984375}]}},
#   {'DetectedText': 'damm',
#    'Type': 'WORD',
#    'Id': 6,
#    'ParentId': 0,
#    'Confidence': 99.96102142333984,
#    'Geometry': {'BoundingBox': {'Width': 0.109375,
#      'Height': 0.046875,
#      'Left': 0.01627604104578495,
#      'Top': 0.0166015625},
#     'Polygon': [{'X': 0.01627604104578495, 'Y': 0.0166015625},
#      {'X': 0.1256510466337204, 'Y': 0.0166015625},
#      {'X': 0.1256510466337204, 'Y': 0.0634765625},
#      {'X': 0.01627604104578495, 'Y': 0.0634765625}]}},
#   {'DetectedText': 'it',
#    'Type': 'WORD',
#    'Id': 7,
#    'ParentId': 0,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.01888020895421505,
#      'Height': 0.044921875,
#      'Left': 0.1393229216337204,
#      'Top': 0.017578125},
#     'Polygon': [{'X': 0.1393229216337204, 'Y': 0.017578125},
#      {'X': 0.158203125, 'Y': 0.017578125},
#      {'X': 0.158203125, 'Y': 0.0625},
#      {'X': 0.1393229216337204, 'Y': 0.0625}]}},
#   {'DetectedText': 'darn',
#    'Type': 'WORD',
#    'Id': 8,
#    'ParentId': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.076171875,
#      'Height': 0.044921875,
#      'Left': 0.0325520820915699,
#      'Top': 0.1552734375},
#     'Polygon': [{'X': 0.0325520820915699, 'Y': 0.1552734375},
#      {'X': 0.1087239608168602, 'Y': 0.1552734375},
#      {'X': 0.1087239608168602, 'Y': 0.2001953125},
#      {'X': 0.0325520820915699, 'Y': 0.2001953125}]}},
#   {'DetectedText': 'it',
#    'Type': 'WORD',
#    'Id': 9,
#    'ParentId': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.01888020895421505,
#      'Height': 0.044921875,
#      'Left': 0.1236979141831398,
#      'Top': 0.1552734375},
#     'Polygon': [{'X': 0.1236979141831398, 'Y': 0.1552734375},
#      {'X': 0.142578125, 'Y': 0.1552734375},
#      {'X': 0.142578125, 'Y': 0.2001953125},
#      {'X': 0.1236979141831398, 'Y': 0.2001953125}]}},
#   {'DetectedText': "IT'S",
#    'Type': 'WORD',
#    'Id': 10,
#    'ParentId': 2,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.13671875,
#      'Height': 0.0966796875,
#      'Left': 0.6751301884651184,
#      'Top': 0.1875},
#     'Polygon': [{'X': 0.6751301884651184, 'Y': 0.1875},
#      {'X': 0.8118489384651184, 'Y': 0.1875},
#      {'X': 0.8118489384651184, 'Y': 0.2841796875},
#      {'X': 0.6751301884651184, 'Y': 0.2841796875}]}},
#   {'DetectedText': 'crap',
#    'Type': 'WORD',
#    'Id': 11,
#    'ParentId': 3,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.076171875,
#      'Height': 0.0478515625,
#      'Left': 0.048828125,
#      'Top': 0.302734375},
#     'Polygon': [{'X': 0.048828125, 'Y': 0.302734375},
#      {'X': 0.125, 'Y': 0.302734375},
#      {'X': 0.125, 'Y': 0.3505859375},
#      {'X': 0.048828125, 'Y': 0.3505859375}]}},
#   {'DetectedText': 'MONDAY',
#    'Type': 'WORD',
#    'Id': 12,
#    'ParentId': 4,
#    'Confidence': 99.38906860351562,
#    'Geometry': {'BoundingBox': {'Width': 0.3971354067325592,
#      'Height': 0.1142578125,
#      'Left': 0.5540364384651184,
#      'Top': 0.3544921875},
#     'Polygon': [{'X': 0.5540364384651184, 'Y': 0.3544921875},
#      {'X': 0.951171875, 'Y': 0.3544921875},
#      {'X': 0.951171875, 'Y': 0.46875},
#      {'X': 0.5540364384651184, 'Y': 0.46875}]}},
#   {'DetectedText': 'but',
#    'Type': 'WORD',
#    'Id': 13,
#    'ParentId': 5,
#    'Confidence': 99.86426544189453,
#    'Geometry': {'BoundingBox': {'Width': 0.080078125,
#      'Height': 0.0625,
#      'Left': 0.6399739384651184,
#      'Top': 0.5283203125},
#     'Polygon': [{'X': 0.6399739384651184, 'Y': 0.5283203125},
#      {'X': 0.7200520634651184, 'Y': 0.5283203125},
#      {'X': 0.7200520634651184, 'Y': 0.5908203125},
#      {'X': 0.6399739384651184, 'Y': 0.5908203125}]}},
#   {'DetectedText': 'keep',
#    'Type': 'WORD',
#    'Id': 14,
#    'ParentId': 5,
#    'Confidence': 99.96537780761719,
#    'Geometry': {'BoundingBox': {'Width': 0.107421875,
#      'Height': 0.080078125,
#      'Left': 0.7350260615348816,
#      'Top': 0.5283203125},
#     'Polygon': [{'X': 0.7350260615348816, 'Y': 0.5283203125},
#      {'X': 0.8424479365348816, 'Y': 0.5283203125},
#      {'X': 0.8424479365348816, 'Y': 0.6083984375},
#      {'X': 0.7350260615348816, 'Y': 0.6083984375}]}}],
#  'TextModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': 'efd0f2f2-61b4-4dfd-b17c-c58327ec9679',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'efd0f2f2-61b4-4dfd-b17c-c58327ec9679',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '5485',
#    'date': 'Sat, 29 Jun 2024 22:47:43 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # Display list of detected unsafe text

# %%
import string

unsafeWords = ["crap", "darn", "damm"]
for textDetection in detectTextResponse["TextDetections"]:
    # strip punctuation before checking match
    text = textDetection["DetectedText"].translate(str.maketrans("", "", string.punctuation))
    if textDetection["Type"] == "WORD" and text in unsafeWords:
        print("Detected unsafe word: {}".format(textDetection["DetectedText"]))
# Out:
# Detected unsafe word: damm
# Detected unsafe word: darn
# Detected unsafe word: crap

# %% [markdown]
# # Show Bounding Boxes Around Detected Objects

# %%
def drawBoundingBoxes(sourceImage, boxes):
    # blue, green, red, grey
    colors = ((255, 255, 255), (255, 255, 255), (76, 182, 252), (52, 194, 123))

    # Download image locally
    imageLocation = temp_folder + os.path.basename(sourceImage)
    s3.download_file(bucket, sourceImage, imageLocation)

    # Draws BB on Image
    bbImage = Image.open(imageLocation)
    draw = ImageDraw.Draw(bbImage)
    width, height = bbImage.size
    col = 0
    maxcol = len(colors)
    line = 3
    for box in boxes:
        x1 = int(box[1]["Left"] * width)
        y1 = int(box[1]["Top"] * height)
        x2 = int(box[1]["Left"] * width + box[1]["Width"] * width)
        y2 = int(box[1]["Top"] * height + box[1]["Height"] * height)

        draw.text((x1, y1), box[0], colors[col])
        for l in range(line):
            draw.rectangle((x1 - l, y1 - l, x2 + l, y2 + l), outline=colors[col])
        col = (col + 1) % maxcol

    imageFormat = "PNG"
    ext = sourceImage.lower()
    if ext.endswith("jpg") or ext.endswith("jpeg"):
        imageFormat = "JPEG"

    bbImage.save(imageLocation, format=imageFormat)

    display(bbImage)

# %%
boxes = []
textDetections = detectTextResponse["TextDetections"]
for textDetection in textDetections:
    boxes.append((textDetection["Type"], textDetection["Geometry"]["BoundingBox"]))

drawBoundingBoxes(imageName, boxes)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x800>

# %% [markdown]
# # Detect Text in Image using Filters and Regions of Interest

# %%
imageName = "content-moderation/media/coffee.jpg"

# %%
display(IImage(url=s3.generate_presigned_url("get_object", Params={"Bucket": bucket, "Key": imageName})))
# Out:
# <img src="https://sagemaker-us-east-1-891377026966.s3.amazonaws.com/content-moderation/media/coffee.jpg?AWSAccessKeyId=ASIA47CRWA6LC2RIUL7N&Signature=kfh5AoIr1%2BAmIwQAlHTQe1Tq9xk%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEH8aCXVzLWVhc3QtMSJHMEUCIQCa3stryoP8OMiRGUjjwICsqsv25tKNYUwabCERds6CiAIgBx7XkUgvTS2yIFSTfpK0CCPyv7Q2p%2B74xbIpBzxn93AqswMIOBAAGgw4OTEzNzcwMjY5NjYiDDpV%2FSxgnsgRMMHntyqQAwc9J5VpM9nHU3WZk91COh11V31LYX%2FRp109Tvi02Xf%2BximPnId3TTi5nYNne7yZMUEWxUPNrdtNkgthvXUJdfCeU1Yw7ku8jq7nGoEQ5bvB6EoDeh5CrfUXSMYuL6295YZzZ893dmF4rRSz%2ByZqFn8GMDqnc62PDaSE2WyCO5t8JSItne1DzDGj3lyWQamlg0U4Mm21CZKEHIKu29l9PEs6SHdHMCux98RDXDaBTFM5U76vGoQr64EPX5%2F7KW868rWQhfIUqAe1JKhElYeeDyCROQyS7osFYfnD79nY4YrGlJ8XPDeelKUmYQcns5YKaSdPKS18EtW7lYKRcLtmhyD6T9pUuQ0YW7tZJuYxmuYcuAf36aGm0AZVfU7fL8C5dO4CjI6TjH6rdpCDC6lEK2WpKwUNdk9W7kfH0E2b3bblQHhUR5qAkyoGjOLMpewAxdGKRB7UiBVBnLIsj7s4%2FQHR%2FCoJmVptc50q4%2FVvqK5HxjXQg0w%2BYdjkCpXuCphy6wEH4gJbLxgiDisX7FIkCGQw1pqCtAY6ngGGsXMj1Z%2FLN8eixwxNLloXIXnpR3GAu4yvijndLY%2FKIMEaGPJOZvMkZ7hvWrIFxc0tIIr9jLPcXthYYOKR7WbPC0W7FOZ7d%2Byku8rtTDGMVcAzQxHKLvCTX%2BkEKkV04YTqW%2BqhiRZVjOi%2BCEZ3sR1BMui5VMmmSMMJ%2Banjd5cnVpemXVis8OskEWrzsKI86yn5aWB7L%2B8XW6GQggVbag%3D%3D&Expires=1719704914"/>

# %%
# Call Amazon Rekognition to detect text in the image
# https://docs.aws.amazon.com/rekognition/latest/dg/API_DetectText.html

detectTextResponse = rekognition.detect_text(
    Image={
        "S3Object": {
            "Bucket": bucket,
            "Name": imageName,
        }
    },
    Filters={
        "WordFilter": {"MinConfidence": 90, "MinBoundingBoxHeight": 0.05, "MinBoundingBoxWidth": 0.02},
        "RegionsOfInterest": [
            {"BoundingBox": {"Width": 0.1, "Height": 0.05, "Left": 0.01, "Top": 0.01}},
        ],
    },
)

# %% [markdown]
# # Review JSON Response from Rekognition Text API (Text Detection)
# In the JSON response below, you will see detected text, confidence score, and additional information.

# %%
display(detectTextResponse)
# Out:
# {'TextDetections': [],
#  'TextModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': 'fd995cf6-d727-43ab-9290-df9951752ab6',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'fd995cf6-d727-43ab-9290-df9951752ab6',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '46',
#    'date': 'Sat, 29 Jun 2024 22:48:40 GMT'},
#   'RetryAttempts': 0}}

# %%
for textDetection in detectTextResponse["TextDetections"]:
    text = textDetection["DetectedText"]
    if textDetection["Type"] == "WORD":
        print("Word: {}".format(textDetection["DetectedText"]))

# %% [markdown]
# # Detect Text in Video
#  Text detection in video is an async operation.
# https://docs.aws.amazon.com/rekognition/latest/dg/text-detecting-video-procedure.html.
#
# - First we start a text detection job which returns a Job Id.
# - We can then call `get_text_detection` to get the job status and after job is complete, we can get object metadata.
# - In production use cases, you would usually use StepFunction or SNS topic to get notified when job is complete.

# %%
videoName = "content-moderation/media/serverless-bytes.mov"

strDetail = "Text detected in video<br>=======================================<br>"
strOverall = "Text in the overall video:<br>=======================================<br>"

# %%
s3VideoUrl = s3.generate_presigned_url("get_object", Params={"Bucket": bucket, "Key": videoName})

videoTag = "<video controls='controls' autoplay width='640' height='360' name='Video' src='{0}'></video>".format(
    s3VideoUrl
)

videoui = "<table><tr><td style='vertical-align: top'>{}</td></tr></table>".format(videoTag)

display(HTML(videoui))
# Out:
# <table><tr><td style='vertical-align: top'><video controls='controls' autoplay width='640' height='360' name='Video' src='https://sagemaker-us-east-1-891377026966.s3.amazonaws.com/content-moderation/media/serverless-bytes.mov?AWSAccessKeyId=ASIA47CRWA6LC2RIUL7N&Signature=BgIE0UmvQe6%2BegCbvfTbFr0Y%2B3M%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEH8aCXVzLWVhc3QtMSJHMEUCIQCa3stryoP8OMiRGUjjwICsqsv25tKNYUwabCERds6CiAIgBx7XkUgvTS2yIFSTfpK0CCPyv7Q2p%2B74xbIpBzxn93AqswMIOBAAGgw4OTEzNzcwMjY5NjYiDDpV%2FSxgnsgRMMHntyqQAwc9J5VpM9nHU3WZk91COh11V31LYX%2FRp109Tvi02Xf%2BximPnId3TTi5nYNne7yZMUEWxUPNrdtNkgthvXUJdfCeU1Yw7ku8jq7nGoEQ5bvB6EoDeh5CrfUXSMYuL6295YZzZ893dmF4rRSz%2ByZqFn8GMDqnc62PDaSE2WyCO5t8JSItne1DzDGj3lyWQamlg0U4Mm21CZKEHIKu29l9PEs6SHdHMCux98RDXDaBTFM5U76vGoQr64EPX5%2F7KW868rWQhfIUqAe1JKhElYeeDyCROQyS7osFYfnD79nY4YrGlJ8XPDeelKUmYQcns5YKaSdPKS18EtW7lYKRcLtmhyD6T9pUuQ0YW7tZJuYxmuYcuAf36aGm0AZVfU7fL8C5dO4CjI6TjH6rdpCDC6lEK2WpKwUNdk9W7kfH0E2b3bblQHhUR5qAkyoGjOLMpewAxdGKRB7UiBVBnLIsj7s4%2FQHR%2FCoJmVptc50q4%2FVvqK5HxjXQg0w%2BYdjkCpXuCphy6wEH4gJbLxgiDisX7FIkCGQw1pqCtAY6ngGGsXMj1Z%2FLN8eixwxNLloXIXnpR3GAu4yvijndLY%2FKIMEaGPJOZvMkZ7hvWrIFxc0tIIr9jLPcXthYYOKR7WbPC0W7FOZ7d%2Byku8rtTDGMVcAzQxHKLvCTX%2BkEKkV04YTqW%2BqhiRZVjOi%2BCEZ3sR1BMui5VMmmSMMJ%2Banjd5cnVpemXVis8OskEWrzsKI86yn5aWB7L%2B8XW6GQggVbag%3D%3D&Expires=1719704933'></video></td></tr></table>

# %% [markdown]
# # Call Rekognition to start a job for text detection

# %%
startTextDetection = rekognition.start_text_detection(
    Video={
        "S3Object": {
            "Bucket": bucket,
            "Name": videoName,
        }
    },
)

textJobId = startTextDetection["JobId"]
display("Job Id: {0}".format(textJobId))
# Out:
# 'Job Id: db5555ad4500cb923834d2ef8fadbc7bff46b2018d8ba6a400488615aced5282'

# %% [markdown]
# # Wait for Text Detection Job to Complete
# In production use cases, you would usually use StepFunction or SNS topic to get notified when job is complete.

# %%
getTextDetection = rekognition.get_text_detection(JobId=textJobId)

while getTextDetection["JobStatus"] == "IN_PROGRESS":
    time.sleep(5)
    print(".", end="")

    getTextDetection = rekognition.get_text_detection(JobId=textJobId)

display(getTextDetection["JobStatus"])
# Out:
# ....
# 'SUCCEEDED'

# %% [markdown]
# # Review Raw JSON Response from Rekognition Text Detection API
# In the JSON response below, you will see list of detected text.
#
# For each detected object, you will see information like `Timestamp`.

# %%
display(getTextDetection)
# Out:
# {'JobStatus': 'SUCCEEDED',
#  'VideoMetadata': {'Codec': 'h264',
#   'DurationMillis': 17886,
#   'Format': 'QuickTime / MOV',
#   'FrameRate': 29.982421875,
#   'FrameHeight': 1080,
#   'FrameWidth': 1920},
#  'TextDetections': [{'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.96946716308594,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88160705566406,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.85247039794922,
#     'Geometry': {'BoundingBox': {'Width': 0.2501761019229889,
#       'Height': 0.04543541744351387,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229505062103271},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.925462543964386},
#       {'X': 0.9640475511550903, 'Y': 0.9229505062103271},
#       {'X': 0.9641839861869812, 'Y': 0.9658737778663635},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.93892669677734,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.64482116699219,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 0,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.55741882324219,
#     'Geometry': {'BoundingBox': {'Width': 0.08734130859375,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.96435546875,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88177490234375,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.8597412109375,
#     'Geometry': {'BoundingBox': {'Width': 0.2507254183292389,
#       'Height': 0.045440901070833206,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229450225830078},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.9254626035690308},
#       {'X': 0.9645968675613403, 'Y': 0.9229450225830078},
#       {'X': 0.9647333025932312, 'Y': 0.965868353843689},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.9287109375,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.64531707763672,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 1000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.5792236328125,
#     'Geometry': {'BoundingBox': {'Width': 0.087890625,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.9695053100586,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88159942626953,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.8584213256836,
#     'Geometry': {'BoundingBox': {'Width': 0.2501761019229889,
#       'Height': 0.04543541744351387,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229505062103271},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.925462543964386},
#       {'X': 0.9640475511550903, 'Y': 0.9229505062103271},
#       {'X': 0.9641839861869812, 'Y': 0.9658737778663635},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.93901062011719,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.64480590820312,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 2000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.57527160644531,
#     'Geometry': {'BoundingBox': {'Width': 0.08734130859375,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.96443176269531,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88226318359375,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.85736846923828,
#     'Geometry': {'BoundingBox': {'Width': 0.2501761019229889,
#       'Height': 0.04543541744351387,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229505062103271},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.925462543964386},
#       {'X': 0.9640475511550903, 'Y': 0.9229505062103271},
#       {'X': 0.9641839861869812, 'Y': 0.9658737778663635},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.9288558959961,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.64678955078125,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 3000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.5721206665039,
#     'Geometry': {'BoundingBox': {'Width': 0.08734130859375,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.96717834472656,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88247680664062,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.85762786865234,
#     'Geometry': {'BoundingBox': {'Width': 0.2507254183292389,
#       'Height': 0.045440901070833206,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229450225830078},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.9254626035690308},
#       {'X': 0.9645968675613403, 'Y': 0.9229450225830078},
#       {'X': 0.9647333025932312, 'Y': 0.965868353843689},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.93436431884766,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.64743041992188,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 4000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.57288360595703,
#     'Geometry': {'BoundingBox': {'Width': 0.087890625,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.97147369384766,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88231658935547,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.8567123413086,
#     'Geometry': {'BoundingBox': {'Width': 0.2507254183292389,
#       'Height': 0.045440901070833206,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229450225830078},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.9254626035690308},
#       {'X': 0.9645968675613403, 'Y': 0.9229450225830078},
#       {'X': 0.9647333025932312, 'Y': 0.965868353843689},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.94293212890625,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.6469497680664,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 5000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.57013702392578,
#     'Geometry': {'BoundingBox': {'Width': 0.087890625,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 99.96149444580078,
#     'Geometry': {'BoundingBox': {'Width': 0.1647948920726776,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.8515625},
#       {'X': 0.1944579780101776, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 99.88127136230469,
#     'Geometry': {'BoundingBox': {'Width': 0.24224853515625,
#       'Height': 0.033203125,
#       'Left': 0.028564453125,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 99.85689544677734,
#     'Geometry': {'BoundingBox': {'Width': 0.2501761019229889,
#       'Height': 0.04543541744351387,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229505062103271},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.925462543964386},
#       {'X': 0.9640475511550903, 'Y': 0.9229505062103271},
#       {'X': 0.9641839861869812, 'Y': 0.9658737778663635},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 99.9229965209961,
#     'Geometry': {'BoundingBox': {'Width': 0.08294677734375,
#       'Height': 0.052734375,
#       'Left': 0.0296630859375,
#       'Top': 0.8515625},
#      'Polygon': [{'X': 0.0296630859375, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.8515625},
#       {'X': 0.11260986328125, 'Y': 0.904296875},
#       {'X': 0.0296630859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 6000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
# ...
#       {'X': 0.9640475511550903, 'Y': 0.9229505062103271},
#       {'X': 0.9641839861869812, 'Y': 0.9658737778663635},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 4,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08330783993005753,
#       'Height': 0.05397802218794823,
#       'Left': 0.02948209084570408,
#       'Top': 0.8513393998146057},
#      'Polygon': [{'X': 0.02948209084570408, 'Y': 0.8526936769485474},
#       {'X': 0.11251837760210037, 'Y': 0.8513393998146057},
#       {'X': 0.11278993636369705, 'Y': 0.9039630889892578},
#       {'X': 0.029753657057881355, 'Y': 0.9053174257278442}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 5,
#     'ParentId': 0,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 6,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 1,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 2,
#     'Confidence': 99.64264678955078,
#     'Geometry': {'BoundingBox': {'Width': 0.0845947265625,
#       'Height': 0.033203125,
#       'Left': 0.18621826171875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.18621826171875, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9248046875},
#       {'X': 0.27081298828125, 'Y': 0.9580078125},
#       {'X': 0.18621826171875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 16000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 3,
#     'Confidence': 99.55358123779297,
#     'Geometry': {'BoundingBox': {'Width': 0.08734130859375,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.923828125},
#       {'X': 0.96405029296875, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': '-',
#     'Type': 'LINE',
#     'Id': 0,
#     'Confidence': 89.62422943115234,
#     'Geometry': {'BoundingBox': {'Width': 0.010937499813735485,
#       'Height': 0.012962962500751019,
#       'Left': 0.08697916567325592,
#       'Top': 0.043518517166376114},
#      'Polygon': [{'X': 0.08697916567325592, 'Y': 0.043518517166376114},
#       {'X': 0.09791667014360428, 'Y': 0.043518517166376114},
#       {'X': 0.09791667014360428, 'Y': 0.05648148059844971},
#       {'X': 0.08697916567325592, 'Y': 0.05648148059844971}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'A',
#     'Type': 'LINE',
#     'Id': 1,
#     'Confidence': 89.61904907226562,
#     'Geometry': {'BoundingBox': {'Width': 0.00494384765625,
#       'Height': 0.0107421875,
#       'Left': 0.2955322265625,
#       'Top': 0.0703125},
#      'Polygon': [{'X': 0.2955322265625, 'Y': 0.0703125},
#       {'X': 0.30047607421875, 'Y': 0.0703125},
#       {'X': 0.30047607421875, 'Y': 0.0810546875},
#       {'X': 0.2955322265625, 'Y': 0.0810546875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'MI',
#     'Type': 'LINE',
#     'Id': 2,
#     'Confidence': 94.97786712646484,
#     'Geometry': {'BoundingBox': {'Width': 0.04998779296875,
#       'Height': 0.01171875,
#       'Left': 0.3900146484375,
#       'Top': 0.0703125},
#      'Polygon': [{'X': 0.3900146484375, 'Y': 0.0703125},
#       {'X': 0.44000244140625, 'Y': 0.0703125},
#       {'X': 0.44000244140625, 'Y': 0.08203125},
#       {'X': 0.3900146484375, 'Y': 0.08203125}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Kashif Imran',
#     'Type': 'LINE',
#     'Id': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.1650751382112503,
#       'Height': 0.05446246266365051,
#       'Left': 0.029478805139660835,
#       'Top': 0.8508383631706238},
#      'Polygon': [{'X': 0.029478805139660835, 'Y': 0.8518428802490234},
#       {'X': 0.1944509595632553, 'Y': 0.8508383631706238},
#       {'X': 0.194553941488266, 'Y': 0.904296338558197},
#       {'X': 0.029581785202026367, 'Y': 0.9053008556365967}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Chris Munns',
#     'Type': 'LINE',
#     'Id': 4,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.177978515625,
#       'Height': 0.0517578125,
#       'Left': 0.7899169325828552,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169325828552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.8525390625},
#       {'X': 0.9678954482078552, 'Y': 0.904296875},
#       {'X': 0.7899169325828552, 'Y': 0.904296875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Senior Solutions Architect',
#     'Type': 'LINE',
#     'Id': 5,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.2427978515625,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.2713623046875, 'Y': 0.92578125},
#       {'X': 0.2713623046875, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Senior Developer Advocate',
#     'Type': 'LINE',
#     'Id': 6,
#     'Confidence': 99.85674285888672,
#     'Geometry': {'BoundingBox': {'Width': 0.2507254183292389,
#       'Height': 0.045440901070833206,
#       'Left': 0.7140079140663147,
#       'Top': 0.9229450225830078},
#      'Polygon': [{'X': 0.7140079140663147, 'Y': 0.9254626035690308},
#       {'X': 0.9645968675613403, 'Y': 0.9229450225830078},
#       {'X': 0.9647333025932312, 'Y': 0.965868353843689},
#       {'X': 0.7141443490982056, 'Y': 0.9683859348297119}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': '-',
#     'Type': 'WORD',
#     'Id': 7,
#     'ParentId': 0,
#     'Confidence': 89.62422943115234,
#     'Geometry': {'BoundingBox': {'Width': 0.010986328125,
#       'Height': 0.0126953125,
#       'Left': 0.08734130859375,
#       'Top': 0.0439453125},
#      'Polygon': [{'X': 0.08734130859375, 'Y': 0.0439453125},
#       {'X': 0.09832763671875, 'Y': 0.0439453125},
#       {'X': 0.09832763671875, 'Y': 0.056640625},
#       {'X': 0.08734130859375, 'Y': 0.056640625}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'A',
#     'Type': 'WORD',
#     'Id': 8,
#     'ParentId': 1,
#     'Confidence': 89.61904907226562,
#     'Geometry': {'BoundingBox': {'Width': 0.00494384765625,
#       'Height': 0.0107421875,
#       'Left': 0.2955322265625,
#       'Top': 0.0703125},
#      'Polygon': [{'X': 0.2955322265625, 'Y': 0.0703125},
#       {'X': 0.30047607421875, 'Y': 0.0703125},
#       {'X': 0.30047607421875, 'Y': 0.0810546875},
#       {'X': 0.2955322265625, 'Y': 0.0810546875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'MI',
#     'Type': 'WORD',
#     'Id': 9,
#     'ParentId': 2,
#     'Confidence': 94.97786712646484,
#     'Geometry': {'BoundingBox': {'Width': 0.0076904296875,
#       'Height': 0.0087890625,
#       'Left': 0.3900146484375,
#       'Top': 0.072265625},
#      'Polygon': [{'X': 0.3900146484375, 'Y': 0.072265625},
#       {'X': 0.397705078125, 'Y': 0.072265625},
#       {'X': 0.397705078125, 'Y': 0.0810546875},
#       {'X': 0.3900146484375, 'Y': 0.0810546875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Kashif',
#     'Type': 'WORD',
#     'Id': 10,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08331607282161713,
#       'Height': 0.05396253615617752,
#       'Left': 0.0294804647564888,
#       'Top': 0.851337194442749},
#      'Polygon': [{'X': 0.0294804647564888, 'Y': 0.8527041673660278},
#       {'X': 0.11252260208129883, 'Y': 0.851337194442749},
#       {'X': 0.11279653757810593, 'Y': 0.9039327502250671},
#       {'X': 0.0297544002532959, 'Y': 0.905299723148346}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Imran',
#     'Type': 'WORD',
#     'Id': 11,
#     'ParentId': 3,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07305908203125,
#       'Height': 0.0498046875,
#       'Left': 0.12139892578125,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.12139892578125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.8544921875},
#       {'X': 0.1944580078125, 'Y': 0.904296875},
#       {'X': 0.12139892578125, 'Y': 0.904296875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Chris',
#     'Type': 'WORD',
#     'Id': 12,
#     'ParentId': 4,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.07196044921875,
#       'Height': 0.0517578125,
#       'Left': 0.7899169921875,
#       'Top': 0.8525390625},
#      'Polygon': [{'X': 0.7899169921875, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.8525390625},
#       {'X': 0.86187744140625, 'Y': 0.904296875},
#       {'X': 0.7899169921875, 'Y': 0.904296875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Munns',
#     'Type': 'WORD',
#     'Id': 13,
#     'ParentId': 4,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.094482421875,
#       'Height': 0.0498046875,
#       'Left': 0.8734130859375,
#       'Top': 0.8544921875},
#      'Polygon': [{'X': 0.8734130859375, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.8544921875},
#       {'X': 0.9678955078125, 'Y': 0.904296875},
#       {'X': 0.8734130859375, 'Y': 0.904296875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 14,
#     'ParentId': 5,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.059326171875,
#       'Height': 0.0322265625,
#       'Left': 0.028564453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.028564453125, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.92578125},
#       {'X': 0.087890625, 'Y': 0.9580078125},
#       {'X': 0.028564453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Solutions',
#     'Type': 'WORD',
#     'Id': 15,
#     'ParentId': 5,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.08624267578125,
#       'Height': 0.0322265625,
#       'Left': 0.09393310546875,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.09393310546875, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.92578125},
#       {'X': 0.18017578125, 'Y': 0.9580078125},
#       {'X': 0.09393310546875, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Architect',
#     'Type': 'WORD',
#     'Id': 16,
#     'ParentId': 5,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.085693359375,
#       'Height': 0.0322265625,
#       'Left': 0.1856689453125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.1856689453125, 'Y': 0.92578125},
#       {'X': 0.2713623046875, 'Y': 0.92578125},
#       {'X': 0.2713623046875, 'Y': 0.9580078125},
#       {'X': 0.1856689453125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Senior',
#     'Type': 'WORD',
#     'Id': 17,
#     'ParentId': 6,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.05987548828125,
#       'Height': 0.0322265625,
#       'Left': 0.714111328125,
#       'Top': 0.92578125},
#      'Polygon': [{'X': 0.714111328125, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.92578125},
#       {'X': 0.77398681640625, 'Y': 0.9580078125},
#       {'X': 0.714111328125, 'Y': 0.9580078125}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Developer',
#     'Type': 'WORD',
#     'Id': 18,
#     'ParentId': 6,
#     'Confidence': 100.0,
#     'Geometry': {'BoundingBox': {'Width': 0.09283447265625,
#       'Height': 0.0419921875,
#       'Left': 0.77947998046875,
#       'Top': 0.9248046875},
#      'Polygon': [{'X': 0.77947998046875, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.9248046875},
#       {'X': 0.872314453125, 'Y': 0.966796875},
#       {'X': 0.77947998046875, 'Y': 0.966796875}]}}},
#   {'Timestamp': 17000,
#    'TextDetection': {'DetectedText': 'Advocate',
#     'Type': 'WORD',
#     'Id': 19,
#     'ParentId': 6,
#     'Confidence': 99.57023620605469,
#     'Geometry': {'BoundingBox': {'Width': 0.087890625,
#       'Height': 0.03515625,
#       'Left': 0.876708984375,
#       'Top': 0.923828125},
#      'Polygon': [{'X': 0.876708984375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.923828125},
#       {'X': 0.964599609375, 'Y': 0.958984375},
#       {'X': 0.876708984375, 'Y': 0.958984375}]}}}],
#  'TextModelVersion': '3.1',
#  'ResponseMetadata': {'RequestId': '15a74a50-cf37-40dd-ac4c-2a5b24c8dae6',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '15a74a50-cf37-40dd-ac4c-2a5b24c8dae6',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '105561',
#    'date': 'Sat, 29 Jun 2024 22:49:37 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # Display Recognized Text in the Video

# %%
flaggedTextInVideo = ["AWS", "Twitter"]

theLines = {}

# Objects detected in each frame
for obj in getTextDetection["TextDetections"]:
    if obj["TextDetection"]["Type"] == "WORD":
        ts = obj["Timestamp"]
        cconfidence = obj["TextDetection"]["Confidence"]
        oname = obj["TextDetection"]["DetectedText"]

        if oname in flaggedTextInVideo:
            print("Found flagged text at {} ms: {} (Confidence: {})".format(ts, oname, round(cconfidence, 2)))

        strDetail = strDetail + "At {} ms: {} (Confidence: {})<br>".format(ts, oname, round(cconfidence, 2))
        if oname in theLines:
            cojb = theLines[oname]
            theLines[oname] = {"Text": oname, "Count": 1 + cojb["Count"]}
        else:
            theLines[oname] = {"Text": oname, "Count": 1}

# Unique objects detected in video
for theLine in theLines:
    strOverall = strOverall + "Name: {}, Count: {}<br>".format(theLine, theLines[theLine]["Count"])

# Display results
display(HTML(strOverall))
# Out:
# Text in the overall video:<br>=======================================<br>Name: Kashif, Count: 18<br>Name: Imran, Count: 18<br>Name: Chris, Count: 18<br>Name: Munns, Count: 18<br>Name: Senior, Count: 36<br>Name: Solutions, Count: 18<br>Name: Architect, Count: 18<br>Name: Developer, Count: 18<br>Name: Advocate, Count: 18<br>Name: -, Count: 1<br>Name: A, Count: 1<br>Name: MI, Count: 1<br>

# %%
listui = "<table><tr><td style='vertical-align: top'>{}</td></tr></table>".format(strDetail)
display(HTML(listui))
# Out:
# <table><tr><td style='vertical-align: top'>Text detected in video<br>=======================================<br>At 0 ms: Kashif (Confidence: 99.94)<br>At 0 ms: Imran (Confidence: 100.0)<br>At 0 ms: Chris (Confidence: 100.0)<br>At 0 ms: Munns (Confidence: 100.0)<br>At 0 ms: Senior (Confidence: 100.0)<br>At 0 ms: Solutions (Confidence: 100.0)<br>At 0 ms: Architect (Confidence: 99.64)<br>At 0 ms: Senior (Confidence: 100.0)<br>At 0 ms: Developer (Confidence: 100.0)<br>At 0 ms: Advocate (Confidence: 99.56)<br>At 1000 ms: Kashif (Confidence: 99.93)<br>At 1000 ms: Imran (Confidence: 100.0)<br>At 1000 ms: Chris (Confidence: 100.0)<br>At 1000 ms: Munns (Confidence: 100.0)<br>At 1000 ms: Senior (Confidence: 100.0)<br>At 1000 ms: Solutions (Confidence: 100.0)<br>At 1000 ms: Architect (Confidence: 99.65)<br>At 1000 ms: Senior (Confidence: 100.0)<br>At 1000 ms: Developer (Confidence: 100.0)<br>At 1000 ms: Advocate (Confidence: 99.58)<br>At 2000 ms: Kashif (Confidence: 99.94)<br>At 2000 ms: Imran (Confidence: 100.0)<br>At 2000 ms: Chris (Confidence: 100.0)<br>At 2000 ms: Munns (Confidence: 100.0)<br>At 2000 ms: Senior (Confidence: 100.0)<br>At 2000 ms: Solutions (Confidence: 100.0)<br>At 2000 ms: Architect (Confidence: 99.64)<br>At 2000 ms: Senior (Confidence: 100.0)<br>At 2000 ms: Developer (Confidence: 100.0)<br>At 2000 ms: Advocate (Confidence: 99.58)<br>At 3000 ms: Kashif (Confidence: 99.93)<br>At 3000 ms: Imran (Confidence: 100.0)<br>At 3000 ms: Chris (Confidence: 100.0)<br>At 3000 ms: Munns (Confidence: 100.0)<br>At 3000 ms: Senior (Confidence: 100.0)<br>At 3000 ms: Solutions (Confidence: 100.0)<br>At 3000 ms: Architect (Confidence: 99.65)<br>At 3000 ms: Senior (Confidence: 100.0)<br>At 3000 ms: Developer (Confidence: 100.0)<br>At 3000 ms: Advocate (Confidence: 99.57)<br>At 4000 ms: Kashif (Confidence: 99.93)<br>At 4000 ms: Imran (Confidence: 100.0)<br>At 4000 ms: Chris (Confidence: 100.0)<br>At 4000 ms: Munns (Confidence: 100.0)<br>At 4000 ms: Senior (Confidence: 100.0)<br>At 4000 ms: Solutions (Confidence: 100.0)<br>At 4000 ms: Architect (Confidence: 99.65)<br>At 4000 ms: Senior (Confidence: 100.0)<br>At 4000 ms: Developer (Confidence: 100.0)<br>At 4000 ms: Advocate (Confidence: 99.57)<br>At 5000 ms: Kashif (Confidence: 99.94)<br>At 5000 ms: Imran (Confidence: 100.0)<br>At 5000 ms: Chris (Confidence: 100.0)<br>At 5000 ms: Munns (Confidence: 100.0)<br>At 5000 ms: Senior (Confidence: 100.0)<br>At 5000 ms: Solutions (Confidence: 100.0)<br>At 5000 ms: Architect (Confidence: 99.65)<br>At 5000 ms: Senior (Confidence: 100.0)<br>At 5000 ms: Developer (Confidence: 100.0)<br>At 5000 ms: Advocate (Confidence: 99.57)<br>At 6000 ms: Kashif (Confidence: 99.92)<br>At 6000 ms: Imran (Confidence: 100.0)<br>At 6000 ms: Chris (Confidence: 100.0)<br>At 6000 ms: Munns (Confidence: 100.0)<br>At 6000 ms: Senior (Confidence: 100.0)<br>At 6000 ms: Solutions (Confidence: 100.0)<br>At 6000 ms: Architect (Confidence: 99.64)<br>At 6000 ms: Senior (Confidence: 100.0)<br>At 6000 ms: Developer (Confidence: 100.0)<br>At 6000 ms: Advocate (Confidence: 99.57)<br>At 7000 ms: Kashif (Confidence: 99.91)<br>At 7000 ms: Imran (Confidence: 100.0)<br>At 7000 ms: Chris (Confidence: 100.0)<br>At 7000 ms: Munns (Confidence: 100.0)<br>At 7000 ms: Senior (Confidence: 100.0)<br>At 7000 ms: Solutions (Confidence: 100.0)<br>At 7000 ms: Architect (Confidence: 99.64)<br>At 7000 ms: Senior (Confidence: 100.0)<br>At 7000 ms: Developer (Confidence: 100.0)<br>At 7000 ms: Advocate (Confidence: 99.55)<br>At 8000 ms: Kashif (Confidence: 99.91)<br>At 8000 ms: Imran (Confidence: 100.0)<br>At 8000 ms: Chris (Confidence: 100.0)<br>At 8000 ms: Munns (Confidence: 100.0)<br>At 8000 ms: Senior (Confidence: 100.0)<br>At 8000 ms: Solutions (Confidence: 100.0)<br>At 8000 ms: Architect (Confidence: 99.64)<br>At 8000 ms: Senior (Confidence: 100.0)<br>At 8000 ms: Developer (Confidence: 100.0)<br>At 8000 ms: Advocate (Confidence: 99.58)<br>At 9000 ms: Kashif (Confidence: 99.9)<br>At 9000 ms: Imran (Confid ...

# %% [markdown]
# # References
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_DetectText.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_StartTextDetection.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_GetTextDetection.html

# %% [markdown]
# # Congratulations!
# You have successfully used Amazon Rekognition to identify text in images an videos.

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
