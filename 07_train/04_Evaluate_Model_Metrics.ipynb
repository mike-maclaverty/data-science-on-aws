# %% [markdown]
# # Evaluate Model with Amazon SageMaker Processing Jobs and Scikit-Learn
#
# Often, distributed data processing frameworks such as Scikit-Learn are used to pre-process data sets in order to prepare them for training.
#
# In this notebook we'll use Amazon SageMaker Processing, and leverage the power of Scikit-Learn in a managed SageMaker environment to run our processing workload.

# %% [markdown]
# # NOTE:  THIS NOTEBOOK WILL TAKE A 5-10 MINUTES TO COMPLETE.
#
# # PLEASE BE PATIENT.

# %% [markdown]
# ![](img/prepare_dataset_bert.png)
#
# ![](img/processing.jpg)

# %% [markdown]
# ## Contents
#
# 1. Setup Environment
# 1. Setup Input Data
# 1. Setup Output Data
# 1. Build a Spark container for running the processing job
# 1. Run the Processing Job using Amazon SageMaker
# 1. Inspect the Processed Output Data

# %% [markdown]
# # Setup Environment
#
# Let's start by specifying:
# * The S3 bucket and prefixes that you use for training and model data. Use the default bucket specified by the Amazon SageMaker session.
# * The IAM role ARN used to give processing and training access to the dataset.

# %%
import sagemaker
import boto3

sess = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sess.default_bucket()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
# %store -r training_job_name

# %%
try:
    training_job_name
    print("[OK]")
except NameError:
    print("+++++++++++++++++++++++++++++++")
    print("[ERROR] Please run the notebooks in the previous TRAIN section before you continue.")
    print("+++++++++++++++++++++++++++++++")
# Out:
# [OK]

# %%
print(training_job_name)
# Out:
# tensorflow-training-2024-07-02-02-08-36-935

# %%
# %store -r raw_input_data_s3_uri

# %%
try:
    raw_input_data_s3_uri
except NameError:
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] Please run the notebooks in the PREPARE section before you continue.")
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")

# %%
print(raw_input_data_s3_uri)
# Out:
# s3://sagemaker-us-east-1-891377026966/amazon-reviews-pds/tsv/

# %%
# %store -r max_seq_length

# %%
try:
    max_seq_length
    print("[OK]")
except NameError:
    print("+++++++++++++++++++++++++++++++")
    print("[ERROR] Please run the notebooks in the previous TRAIN section before you continue.")
    print("+++++++++++++++++++++++++++++++")
# Out:
# [OK]

# %%
print(max_seq_length)
# Out:
# 64

# %%
# %store -r experiment_name

# %%
try:
    experiment_name
    print("[OK]")
except NameError:
    print("+++++++++++++++++++++++++++++++")
    print("[ERROR] Please run the notebooks in the previous TRAIN section before you continue.")
    print("+++++++++++++++++++++++++++++++")
# Out:
# [OK]

# %%
print(experiment_name)
# Out:
# Amazon-Customer-Reviews-BERT-Experiment-1719873607

# %%
# %store -r trial_name

# %%
try:
    trial_name
    print("[OK]")
except NameError:
    print("+++++++++++++++++++++++++++++++")
    print("[ERROR] Please run the notebooks in the previous TRAIN section before you continue.")
    print("+++++++++++++++++++++++++++++++")
# Out:
# [OK]

# %%
print(trial_name)
# Out:
# trial-1719873613

# %%
print(training_job_name)
# Out:
# tensorflow-training-2024-07-02-02-08-36-935

# %%
from sagemaker.tensorflow.estimator import TensorFlow

describe_training_job_response = sm.describe_training_job(TrainingJobName=training_job_name)
print(describe_training_job_response)
# Out:
# {'TrainingJobName': 'tensorflow-training-2024-07-02-02-08-36-935', 'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:891377026966:training-job/tensorflow-training-2024-07-02-02-08-36-935', 'ModelArtifacts': {'S3ModelArtifacts': 's3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/output/model.tar.gz'}, 'TrainingJobStatus': 'Completed', 'SecondaryStatus': 'Completed', 'HyperParameters': {'enable_checkpointing': 'false', 'enable_sagemaker_debugger': 'true', 'enable_tensorboard': 'true', 'epochs': '3', 'epsilon': '1e-08', 'freeze_bert_layer': 'false', 'learning_rate': '1e-05', 'max_seq_length': '64', 'model_dir': '"s3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/model"', 'run_sample_predictions': 'true', 'run_test': 'true', 'run_validation': 'true', 'sagemaker_container_log_level': '20', 'sagemaker_job_name': '"tensorflow-training-2024-07-02-02-08-36-935"', 'sagemaker_program': '"tf_bert_reviews.py"', 'sagemaker_region': '"us-east-1"', 'sagemaker_submit_directory': '"s3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/source/sourcedir.tar.gz"', 'test_batch_size': '128', 'test_steps': '100', 'train_batch_size': '128', 'train_steps_per_epoch': '100', 'use_amp': 'true', 'use_xla': 'true', 'validation_batch_size': '128', 'validation_steps': '100'}, 'AlgorithmSpecification': {'TrainingImage': '763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:2.3.1-cpu-py37', 'TrainingInputMode': 'File', 'MetricDefinitions': [{'Name': 'train:loss', 'Regex': 'loss: ([0-9\\.]+)'}, {'Name': 'train:accuracy', 'Regex': 'accuracy: ([0-9\\.]+)'}, {'Name': 'validation:loss', 'Regex': 'val_loss: ([0-9\\.]+)'}, {'Name': 'validation:accuracy', 'Regex': 'val_accuracy: ([0-9\\.]+)'}], 'EnableSageMakerMetricsTimeSeries': True}, 'RoleArn': 'arn:aws:iam::891377026966:role/service-role/AmazonSageMaker-ExecutionRole-20240628T190970', 'InputDataConfig': [{'ChannelName': 'train', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/output/bert-train', 'S3DataDistributionType': 'ShardedByS3Key'}}, 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/output/bert-validation', 'S3DataDistributionType': 'ShardedByS3Key'}}, 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'test', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/output/bert-test', 'S3DataDistributionType': 'ShardedByS3Key'}}, 'CompressionType': 'None', 'RecordWrapperType': 'None'}], 'OutputDataConfig': {'KmsKeyId': '', 'S3OutputPath': 's3://sagemaker-us-east-1-891377026966/', 'CompressionType': 'GZIP'}, 'ResourceConfig': {'InstanceType': 'ml.c5.4xlarge', 'InstanceCount': 1, 'VolumeSizeInGB': 1024}, 'StoppingCondition': {'MaxRuntimeInSeconds': 86400}, 'CreationTime': datetime.datetime(2024, 7, 2, 2, 8, 38, 921000, tzinfo=tzlocal()), 'TrainingStartTime': datetime.datetime(2024, 7, 2, 2, 9, 14, 332000, tzinfo=tzlocal()), 'TrainingEndTime': datetime.datetime(2024, 7, 2, 2, 49, 23, 723000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2024, 7, 2, 2, 51, 29, 794000, tzinfo=tzlocal()), 'SecondaryStatusTransitions': [{'Status': 'Starting', 'StartTime': datetime.datetime(2024, 7, 2, 2, 8, 38, 921000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2024, 7, 2, 2, 9, 14, 332000, tzinfo=tzlocal()), 'StatusMessage': 'Preparing the instances for training'}, {'Status': 'Downloading', 'StartTime': datetime.datetime(2024, 7, 2, 2, 9, 14, 332000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2024, 7, 2, 2, 10, 5, 187000, tzinfo=tzlocal()), 'StatusMessage': 'Downloading the training image'}, {'Status': 'Tr ...

# %%
model_dir_s3_uri = describe_training_job_response["ModelArtifacts"]["S3ModelArtifacts"].replace("model.tar.gz", "")
model_dir_s3_uri
# Out:
# 's3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/output/'

# %% [markdown]
# # Run the Processing Job using Amazon SageMaker
#
# Next, use the Amazon SageMaker Python SDK to submit a processing job using our custom python script.

# %% [markdown]
# # Create the `Experiment Config`

# %%
experiment_config = {
    "ExperimentName": experiment_name,
    "TrialName": trial_name,
    "TrialComponentDisplayName": "evaluate",
}

# %% [markdown]
# # Set the Processing Job Hyper-Parameters

# %%
processing_instance_type = "ml.t3.xlarge"
processing_instance_count = 1

# %% [markdown]
# # Choosing a `max_seq_length` for BERT
# Since a smaller `max_seq_length` leads to faster training and lower resource utilization, we want to find the smallest review length that captures `80%` of our reviews.
#
# Remember our distribution of review lengths from a previous section?
#
# ```
# mean         51.683405
# std         107.030844
# min           1.000000
# 10%           2.000000
# 20%           7.000000
# 30%          19.000000
# 40%          22.000000
# 50%          26.000000
# 60%          32.000000
# 70%          43.000000
# 80%          63.000000
# 90%         110.000000
# 100%       5347.000000
# max        5347.000000
# ```
#
# ![](img/review_word_count_distribution.png)
#
# Review length `63` represents the `80th` percentile for this dataset.  However, it's best to stick with powers-of-2 when using BERT.  So let's choose `64` as this is the smallest power-of-2 greater than `63`.  Reviews with length > `64` will be truncated to `64`.

# %%
from sagemaker.sklearn.processing import SKLearnProcessor

processor = SKLearnProcessor(
    framework_version="0.23-1",
    role=role,
    instance_type=processing_instance_type,
    instance_count=processing_instance_count,
    max_runtime_in_seconds=7200,
)

# %%
from sagemaker.processing import ProcessingInput, ProcessingOutput

processor.run(
    code="evaluate_model_metrics.py",
    inputs=[
        ProcessingInput(
            input_name="model-tar-s3-uri", source=model_dir_s3_uri, destination="/opt/ml/processing/input/model/"
        ),
        ProcessingInput(
            input_name="evaluation-data-s3-uri",
            source=raw_input_data_s3_uri,
            destination="/opt/ml/processing/input/data/",
        ),
    ],
    outputs=[
        ProcessingOutput(s3_upload_mode="EndOfJob", output_name="metrics", source="/opt/ml/processing/output/metrics"),
    ],
    arguments=["--max-seq-length", str(max_seq_length)],
    experiment_config=experiment_config,
    logs=True,
    wait=False,
)
# Out:
# INFO:sagemaker:Creating processing-job with name sagemaker-scikit-learn-2024-07-02-18-40-05-240

# %%
scikit_processing_job_name = processor.jobs[-1].describe()["ProcessingJobName"]
print(scikit_processing_job_name)
# Out:
# sagemaker-scikit-learn-2024-07-02-18-40-05-240

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/processing-jobs/{}">Processing Job</a></b>'.format(
            region, scikit_processing_job_name
        )
    )
)
# Out:
# /tmp/ipykernel_99/1926661146.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/processing-jobs/sagemaker-scikit-learn-2024-07-02-18-40-05-240">Processing Job</a></b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region={}#logStream:group=/aws/sagemaker/ProcessingJobs;prefix={};streamFilter=typeLogStreamPrefix">CloudWatch Logs</a> After About 5 Minutes</b>'.format(
            region, scikit_processing_job_name
        )
    )
)
# Out:
# /tmp/ipykernel_99/267036670.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#logStream:group=/aws/sagemaker/ProcessingJobs;prefix=sagemaker-scikit-learn-2024-07-02-18-40-05-240;streamFilter=typeLogStreamPrefix">CloudWatch Logs</a> After About 5 Minutes</b>

# %%
from IPython.core.display import display, HTML

display(
    HTML(
        '<b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/{}/{}/?region={}&tab=overview">S3 Output Data</a> After The Processing Job Has Completed</b>'.format(
            bucket, scikit_processing_job_name, region
        )
    )
)
# Out:
# /tmp/ipykernel_99/2163845711.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/?region=us-east-1&tab=overview">S3 Output Data</a> After The Processing Job Has Completed</b>

# %% [markdown]
# # Monitor the Processing Job

# %%
running_processor = sagemaker.processing.ProcessingJob.from_processing_name(
    processing_job_name=scikit_processing_job_name, sagemaker_session=sess
)

processing_job_description = running_processor.describe()

print(processing_job_description)
# Out:
# {'ProcessingInputs': [{'InputName': 'model-tar-s3-uri', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/output/', 'LocalPath': '/opt/ml/processing/input/model/', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'evaluation-data-s3-uri', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-891377026966/amazon-reviews-pds/tsv/', 'LocalPath': '/opt/ml/processing/input/data/', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'code', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/input/code/evaluate_model_metrics.py', 'LocalPath': '/opt/ml/processing/input/code', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}], 'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'metrics', 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/output/metrics', 'LocalPath': '/opt/ml/processing/output/metrics', 'S3UploadMode': 'EndOfJob'}, 'AppManaged': False}]}, 'ProcessingJobName': 'sagemaker-scikit-learn-2024-07-02-18-40-05-240', 'ProcessingResources': {'ClusterConfig': {'InstanceCount': 1, 'InstanceType': 'ml.t3.xlarge', 'VolumeSizeInGB': 30}}, 'StoppingCondition': {'MaxRuntimeInSeconds': 7200}, 'AppSpecification': {'ImageUri': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3', 'ContainerEntrypoint': ['python3', '/opt/ml/processing/input/code/evaluate_model_metrics.py'], 'ContainerArguments': ['--max-seq-length', '64']}, 'RoleArn': 'arn:aws:iam::891377026966:role/service-role/AmazonSageMaker-ExecutionRole-20240628T190970', 'ExperimentConfig': {'ExperimentName': 'Amazon-Customer-Reviews-BERT-Experiment-1719873607', 'TrialName': 'trial-1719873613', 'TrialComponentDisplayName': 'evaluate'}, 'ProcessingJobArn': 'arn:aws:sagemaker:us-east-1:891377026966:processing-job/sagemaker-scikit-learn-2024-07-02-18-40-05-240', 'ProcessingJobStatus': 'InProgress', 'LastModifiedTime': datetime.datetime(2024, 7, 2, 18, 40, 6, 839000, tzinfo=tzlocal()), 'CreationTime': datetime.datetime(2024, 7, 2, 18, 40, 6, 85000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '4662eaa9-a4bb-409c-a3ab-84bf42b13f6b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '4662eaa9-a4bb-409c-a3ab-84bf42b13f6b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '2444', 'date': 'Tue, 02 Jul 2024 18:40:22 GMT'}, 'RetryAttempts': 0}}

# %%
processing_evaluation_metrics_job_name = processing_job_description["ProcessingJobName"]
print(processing_evaluation_metrics_job_name)
# Out:
# sagemaker-scikit-learn-2024-07-02-18-40-05-240

# %%
# %%time

running_processor.wait(logs=False)
# Out:
# .................................................................................................................................................................................................................!CPU times: user 953 ms, sys: 129 ms, total: 1.08 s
# Wall time: 17min 39s

# %% [markdown]
# # _Please Wait Until the ^^ Processing Job ^^ Completes Above._

# %% [markdown]
# # Inspect the Processed Output Data
#
# Take a look at a few rows of the transformed dataset to make sure the processing was successful.

# %%
processing_job_description = running_processor.describe()

output_config = processing_job_description["ProcessingOutputConfig"]
for output in output_config["Outputs"]:
    if output["OutputName"] == "metrics":
        processed_metrics_s3_uri = output["S3Output"]["S3Uri"]

print(processed_metrics_s3_uri)
# Out:
# s3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/output/metrics

# %%
# !aws s3 ls $processed_metrics_s3_uri/
# Out:
# 2024-07-02 18:57:56         41 evaluation.json

# %% [markdown]
# ## Show the test accuracy

# %%
import json
from pprint import pprint

evaluation_json = sagemaker.s3.S3Downloader.read_file("{}/evaluation.json".format(processed_metrics_s3_uri))

pprint(json.loads(evaluation_json))
# Out:
# {'metrics': {'accuracy': {'value': 0.6}}}

# %%
# !aws s3 cp $processed_metrics_s3_uri/confusion_matrix.png ./model_evaluation/

# import time

# time.sleep(10)  # Slight delay for our notebook to recognize the newly-downloaded file

# %%
# %%html

# <img src='./model_evaluation/confusion_matrix.png'>

# %% [markdown]
# # Pass Variables to the Next Notebook(s)

# %%
# %store processing_evaluation_metrics_job_name
# Out:
# Stored 'processing_evaluation_metrics_job_name' (str)

# %%
# %store processed_metrics_s3_uri
# Out:
# Stored 'processed_metrics_s3_uri' (str)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# balance_dataset                                       -> True
# balanced_bias_data_jsonlines_s3_uri                   -> 's3://sagemaker-us-east-1-891377026966/bias-detect
# balanced_bias_data_s3_uri                             -> 's3://sagemaker-us-east-1-891377026966/bias-detect
# bias_data_s3_uri                                      -> 's3://sagemaker-us-east-1-891377026966/bias-detect
# experiment_name                                       -> 'Amazon-Customer-Reviews-BERT-Experiment-171987360
# feature_group_name                                    -> 'reviews-feature-group-1719873648'
# feature_store_offline_prefix                          -> 'reviews-feature-store-1719873648'
# ingest_create_athena_db_passed                        -> True
# ingest_create_athena_table_parquet_passed             -> True
# ingest_create_athena_table_tsv_passed                 -> True
# max_seq_length                                        -> 64
# processed_metrics_s3_uri                              -> 's3://sagemaker-us-east-1-891377026966/sagemaker-s
# processed_test_data_s3_uri                            -> 's3://sagemaker-us-east-1-891377026966/sagemaker-s
# processed_train_data_s3_uri                           -> 's3://sagemaker-us-east-1-891377026966/sagemaker-s
# processed_validation_data_s3_uri                      -> 's3://sagemaker-us-east-1-891377026966/sagemaker-s
# processing_evaluation_metrics_job_name                -> 'sagemaker-scikit-learn-2024-07-02-18-40-05-240'
# raw_input_data_s3_uri                                 -> 's3://sagemaker-us-east-1-891377026966/amazon-revi
# s3_private_path_tsv                                   -> 's3://sagemaker-us-east-1-891377026966/amazon-revi
# s3_public_path_tsv                                    -> 's3://dsoaws/amazon-reviews-pds/tsv'
# test_data_bias_s3_uri                                 -> 's3://sagemaker-us-east-1-891377026966/bias/test_d
# test_split_percentage                                 -> 0.05
# train_split_percentage                                -> 0.9
# training_job_name                                     -> 'tensorflow-training-2024-07-02-02-08-36-935'
# trial_name                                            -> 'trial-1719873613'
# validation_split_percentage                           -> 0.05

# %% [markdown]
# # Show the Experiment Tracking Lineage

# %%
from sagemaker.analytics import ExperimentAnalytics

import pandas as pd

pd.set_option("max_colwidth", 500)

experiment_analytics = ExperimentAnalytics(
    sagemaker_session=sess, experiment_name=experiment_name, sort_by="CreationTime", sort_order="Descending"
)

experiment_analytics_df = experiment_analytics.dataframe()
experiment_analytics_df
# Out:
#                                                   TrialComponentName  \
# 0  sagemaker-scikit-learn-2024-07-02-18-40-05-240-aws-processing-job
# 1       tensorflow-training-2024-07-02-02-08-36-935-aws-training-job
# 2  sagemaker-scikit-learn-2024-07-01-22-42-17-522-aws-processing-job
#
#   DisplayName  \
# 0    evaluate
# 1       train
# 2     prepare
#
#                                                                                                 SourceArn  \
# 0  arn:aws:sagemaker:us-east-1:891377026966:processing-job/sagemaker-scikit-learn-2024-07-02-18-40-05-240
# 1       arn:aws:sagemaker:us-east-1:891377026966:training-job/tensorflow-training-2024-07-02-02-08-36-935
# 2  arn:aws:sagemaker:us-east-1:891377026966:processing-job/sagemaker-scikit-learn-2024-07-01-22-42-17-522
#
#    SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                      1.0           ml.t3.xlarge                      30.0
# 1                      1.0          ml.c5.4xlarge                    1024.0
# 2                      2.0           ml.t3.xlarge                      30.0
#
#    SageMaker.ImageUri - MediaType  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
#
#                                                            SageMaker.ImageUri - Value  \
# 0  683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3
# 1                                                                                 NaN
# 2  683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3
#
#    code - MediaType  \
# 0               NaN
# 1               NaN
# 2               NaN
#
#                                                                                                                                       code - Value  \
# 0                        s3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/input/code/evaluate_model_metrics.py
# 1                                                                                                                                              NaN
# 2  s3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/input/code/preprocess-scikit-text-to-bert-feature-store.py
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#                                                                          SageMaker.ModelArtifact - Value  \
# 0                                                                                                    NaN
# 1  s3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/output/model.tar.gz
# 2                                                                                                    NaN
#
#   AWS_DEFAULT_REGION  raw-input-data - MediaType  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2          us-east-1                         NaN
#
#                                           raw-input-data - Value  \
# 0                                                            NaN
# 1                                                            NaN
# 2  s3://sagemaker-us-east-1-891377026966/amazon-reviews-pds/tsv/
#
#    bert-test - MediaType  \
# 0                    NaN
# 1                    NaN
# 2                    NaN
#
#                                                                                        bert-test - Value  \
# 0                                                                                                    NaN
# 1                                                                                                    NaN
# 2  s3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/output/bert-test
#
#   bert-train - MediaType  \
# 0                    NaN
# 1                    NaN
# 2                    NaN
#
#                                                                                        bert-train - Value  \
# 0                                                                                                     NaN
# 1                                                                                                     NaN
# 2  s3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/output/bert-train
#
#   bert-validation - MediaType  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
#
#                                                                                        bert-validation - Value
# 0                                                                                                          NaN
# 1                                                                                                          NaN
# 2  s3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-01-22-42-17-522/output/bert-validation
#
# [3 rows x 143 columns]

# %%
trial_component_name = experiment_analytics_df.TrialComponentName[0]
print(trial_component_name)
# Out:
# sagemaker-scikit-learn-2024-07-02-18-40-05-240-aws-processing-job

# %%
trial_component_description = sm.describe_trial_component(TrialComponentName=trial_component_name)
trial_component_description
# Out:
# {'TrialComponentName': 'sagemaker-scikit-learn-2024-07-02-18-40-05-240-aws-processing-job',
#  'TrialComponentArn': 'arn:aws:sagemaker:us-east-1:891377026966:experiment-trial-component/sagemaker-scikit-learn-2024-07-02-18-40-05-240-aws-processing-job',
#  'DisplayName': 'evaluate',
#  'Source': {'SourceArn': 'arn:aws:sagemaker:us-east-1:891377026966:processing-job/sagemaker-scikit-learn-2024-07-02-18-40-05-240',
#   'SourceType': 'SageMakerProcessingJob'},
#  'Status': {'PrimaryStatus': 'Completed',
#   'Message': 'Status: Completed, exit message: null, failure reason: null'},
#  'StartTime': datetime.datetime(2024, 7, 2, 18, 45, 54, tzinfo=tzlocal()),
#  'EndTime': datetime.datetime(2024, 7, 2, 18, 58, 1, tzinfo=tzlocal()),
#  'CreationTime': datetime.datetime(2024, 7, 2, 18, 40, 6, 756000, tzinfo=tzlocal()),
#  'CreatedBy': {'UserProfileArn': 'arn:aws:sagemaker:us-east-1:891377026966:user-profile/d-fu4acyc03cpg/default-20240628T190970',
#   'UserProfileName': 'default-20240628T190970',
#   'DomainId': 'd-fu4acyc03cpg'},
#  'LastModifiedTime': datetime.datetime(2024, 7, 2, 18, 58, 1, 719000, tzinfo=tzlocal()),
#  'LastModifiedBy': {},
#  'Parameters': {'SageMaker.InstanceCount': {'NumberValue': 1.0},
#   'SageMaker.InstanceType': {'StringValue': 'ml.t3.xlarge'},
#   'SageMaker.VolumeSizeInGB': {'NumberValue': 30.0}},
#  'InputArtifacts': {'SageMaker.ImageUri': {'Value': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3'},
#   'code': {'Value': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/input/code/evaluate_model_metrics.py'},
#   'evaluation-data-s3-uri': {'Value': 's3://sagemaker-us-east-1-891377026966/amazon-reviews-pds/tsv/'},
#   'model-tar-s3-uri': {'Value': 's3://sagemaker-us-east-1-891377026966/tensorflow-training-2024-07-02-02-08-36-935/output/'}},
#  'OutputArtifacts': {'metrics': {'Value': 's3://sagemaker-us-east-1-891377026966/sagemaker-scikit-learn-2024-07-02-18-40-05-240/output/metrics'}},
#  'Metrics': [],
#  'LineageGroupArn': 'arn:aws:sagemaker:us-east-1:891377026966:lineage-group/sagemaker-default-lineage-group',
#  'Sources': [],
#  'ResponseMetadata': {'RequestId': '3e6da151-6d2b-4d4d-93f8-ed4a607de8eb',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '3e6da151-6d2b-4d4d-93f8-ed4a607de8eb',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1820',
#    'date': 'Tue, 02 Jul 2024 19:02:44 GMT'},
#   'RetryAttempts': 0}}

# %%
from sagemaker.lineage.visualizer import LineageTableVisualizer

lineage_table_viz = LineageTableVisualizer(sess)
lineage_table_viz_df = lineage_table_viz.show(processing_job_name=processing_evaluation_metrics_job_name)
lineage_table_viz_df
# Out:
#                                         Name/Source Direction     Type  \
# 0  s3://...240/input/code/evaluate_model_metrics.py     Input  DataSet
# 1  s3://...t-1-891377026966/amazon-reviews-pds/tsv/     Input  DataSet
# 2  s3://...training-2024-07-02-02-08-36-935/output/     Input  DataSet
# 3  68331...om/sagemaker-scikit-learn:0.23-1-cpu-py3     Input    Image
# 4  s3://...n-2024-07-02-18-40-05-240/output/metrics    Output  DataSet
#
#   Association Type Lineage Type
# 0    ContributedTo     artifact
# 1    ContributedTo     artifact
# 2    ContributedTo     artifact
# 3    ContributedTo     artifact
# 4         Produced     artifact

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
